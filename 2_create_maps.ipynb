# %%
# If you do not have plotly installed, uncomment the line and run this cell
# Install kaleido for writing the maps to a png file

# !pip install plotly
# !pip install -U kaleido

# To retrieve the topojson github, uncomment the line and run the cell
# !git clone https://github.com/sgillies/topojson.git
# Out:
# fatal: destination path 'topojson' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import topojson  
from topojson import topojson
import json
import requests
import plotly.graph_objs as go
import plotly.offline as pyo
import plotly.io as pio
from kaleido.scopes.plotly import PlotlyScope

# %% [markdown]
# #### Much of the code here was adapted for our project from this Texas bivariate choropleth map example:
# #### https://chart-studio.plotly.com/~empet/15191/texas-bivariate-choropleth-assoc/#/
#
# #### NOTE: While the topojson map of Europe includes all european countries, our covid data only cover European Union countries

# %%
'''
Function assigns what each countries color will be for each week

Parameters:
delta_data, var_data: lists or 1d arrays, containing values of the two variables
*_bound_* variables: bounds that determine what data values will be mapped to which color 
biv_colors: contains color code


'''

def data_to_color(delta_data, var_data, delta_bound_1, delta_bound_2, var_bound_1, var_bound_2, biv_colors):
    # This function works only with a list of 9 bivariate colors
    
    if len(delta_data) != len(var_data):
        raise ValueError('the list of delta_data and var_data must have the same length')
    n_colors = len(biv_colors)
    
    if n_colors != 9:
        raise ValueError('the list of bivariate colors must have the length equal to 9')
    
    num = 3
    xcol = [set_interval_value(vals, var_bound_1, var_bound_2) for vals in var_data]
    ycol = [set_interval_value(vals, delta_bound_1, delta_bound_2) for vals in delta_data]
    idxcol = [int(xcolor + num*ycolor) for xcolor, ycolor in zip(xcol,ycol)]# index of the corresponding color in the list of bivariate colors
    colors = np.array(biv_colors)[idxcol]
    
    return list(colors)

# %%
# Function assigns the countries float value to an integer bound

def set_interval_value(vals, bound_1, bound_2):
    if vals <= bound_1:
        return 0
    elif bound_1 < vals <= bound_2:
        return 1
    else:
        return 2

# %%
# Makes the colorsquare legend for the bivariate map

def colorsquare(delta_text, var_text, colorscale, num=3, xaxis='x2', yaxis='y2'):

    z = [[j + num * i for j in range(num)] for i in range(num)]
    n = len(delta_text)
    if len(delta_text) != n or len(var_text) != n or len(colorscale) != 2 * n ** 2:
        raise ValueError('Your lists of strings  must have the length {n} and the colorscale, {n**2}')

    text = [[delta_text[j] + '<br>' + var_text[i] for j in range(len(delta_text))] for i in range(len(var_text))]
    return go.Heatmap(x=list(range(n)),
                      y=list(range(n)),
                      z=z,
                      xaxis=xaxis,
                      yaxis=yaxis,
                      text=text,
                      hoverinfo='text',
                      colorscale=colorscale,
                      showscale=False)

# %%
# Returns a discrete colorscale defined by biv_colors

def colors_to_colorscale(biv_colors):
    num = len(biv_colors)
    biv_colorscale = []
    
    for i, col in enumerate(biv_colors):
        biv_colorscale.extend([[round(i/num, 2) , col], [round((i+1)/num, 2), col]])
    
    return biv_colorscale

# %%
# Creates the map for each week given the dataframe, the color scheme, the variant to show with 
# delta, the country, week, and bounds

def generate_map(prep_map_data, bi_color, var_type, all_countries, week, bounds):

    # extract the values for the delta column and the other variants column
    delta_list = [prep_map_data.loc[country, 'Delta'] for country in all_countries]
    var_list = [prep_map_data.loc[country, var_type] for country in all_countries]

    # assigns each data point in the lists to the appropriate bivariate color
    country_color = data_to_color(delta_list, var_list, bounds[0], bounds[1], bounds[0],
                                  bounds[1], bi_color)

    # text for interactive map when cursor is hovered over a country
    text = [c + '<br>Delta Cases Percent: ' + '{:0.4f}'.format(d) + '<br>' + var_type + ' Cases Percent: ' + '{:0.4f}'.format(v)
            for c, d, v in zip(countries, delta_list, var_list)]

    # creating each country object
    country_centers = dict(type='scatter',
                          y=lats,
                          x=lons,
                          mode='markers',
                          text=text,
                          marker=dict(size=1, color=country_color),
                          showlegend=False,
                          hoverinfo='text')

    # defining the map geometrical boundaries for the countries and filling it with color
    n = len(bi_color)
    data = []
    fc = np.array(country_color)
    for num in range(9):
        idx_color = np.where(fc == bi_color[num])[0]
        for i in idx_color:
            pts = []
            feature = geoJSON['features'][i]
            if feature['geometry']['type'] == 'Polygon':
                pts.extend(feature['geometry']['coordinates'][0])
                pts.append([None, None])  # mark the end of a polygon

            elif feature['geometry']['type'] == 'MultiPolygon':
                for polyg in feature['geometry']['coordinates']:
                    pts.extend(polyg[0])
                    pts.append([None, None])  # end of polygon
            else:
                raise ValueError("geometry type irrelevant for a map")

            coor_x, coor_y = zip(*pts)
            data.append(dict(type='scatter',
                             x=coor_x, y=coor_y,
                             fill='toself',
                             fillcolor=bi_color[num],  # country_color[i],
                             hoverinfo='none',
                             mode='lines',
                             line=dict(width=1, color='rgb(150,150,150)'),
                             opacity=0.95)
                        )
    data.append(country_centers)

    # text for interactive bivariate legend
    delta_text = ['Delta < P_33', 'P_33 <= Delta <= P_66 ', 'Delta > P_66']
    var_text = [var_type + ' < P_33', 'P_33 <= ' + var_type + ' <= P_66 ', var_type + ' > P_66']

    #creating the legend
    legend = colorsquare(var_text, delta_text, colors_to_colorscale(bi_color))
    data.append(legend)

    legend_axis = dict(showline=False, zeroline=False, showgrid=False, ticks='', showticklabels=False)

    layout = dict(title='Covid Variants Bivariate Choropleth Map<br>Percent for the Week of ' + week + '<br>Colors determined by the 33rd and 66th percentiles of the data',
                  font=dict(family='Balto'),
                  showlegend=False,
                  hovermode='closest',
                  xaxis=dict(autorange=False,
                             range=[-29.1, 55],  # an interval of lons that covers Europe
                             domain=[0, 1],
                             showgrid=False,
                             zeroline=False,
                             fixedrange=True,
                             ticks='',
                             showticklabels=False),
                  yaxis=dict(autorange=False,
                             range=[34, 72.1],  # an interval of lats that cover Europe
                             domain=[0, 1],
                             showgrid=False,
                             zeroline=False,
                             ticks='',
                             showticklabels=False,
                             fixedrange=True),
                  xaxis2=dict(legend_axis, **dict(domain=[0.065, 0.25],
                                                  anchor='y2',
                                                  side='bottom',
                                                  title='    ' + str(round(bounds[0], 3)) + '      ' + str(round(bounds[1], 3)) + '<br>' + var_type + ' Cases Per 100,000',
                                                  titlefont=dict(size=12))),
                  yaxis2=dict(legend_axis, **dict(domain=[.61, 0.75],
                                                  anchor='x2',
                                                  side='left',
                                                  title='Delta Cases Per 100,000<br> ' + str(round(bounds[0], 3)) + '    ' + str(round(bounds[1], 3)),
                                                  titlefont=dict(size=12))),
                  width=1100,
                  height=850,
                  dragmode='select')
    #scope=PlotlyScope(plotlyjs='https://cdn.plot.ly/plotly-latest.min.js')

    # Taking the dict with all the data and layout settings and creating a png
    fig = go.Figure(dict(data=data, layout = layout))
    #fig.write_image(fig,'Images/' + week + '.png', engine='auto')
    
    with open('png_files/' + week + '.png', 'x'):
        pio.write_image(fig=fig, file='png_files/' + week + '.png', format='png')

    #pyo.plot(fig, filename=week +'.html') #THIS FOR INTERACTIVE HTML figures

# %% [markdown]
# ### Load the JSON map of Europe

# %%
url_europe = 'https://gist.githubusercontent.com/milafrerichs/69035da4707ea51886eb/raw/4cb1783c2904f52cbb8a258ee96031f9054d155b/eu.topojson'
my_file = requests.get(url_europe)
topoJSON = json.loads(my_file.content)

topo_features = topoJSON['objects']['europe']['geometries']
scale = topoJSON['transform']['scale']
translation = topoJSON['transform']['translate']

# %% [markdown]
# ### Convert Europe topoJSON data into a geojson dictionary

# %%
geoJSON = dict(type= 'FeatureCollection',
             features = [])

for k, tfeature in enumerate(topo_features):
    geo_feature = dict(id=k, type= "Feature")
    geo_feature['properties'] = tfeature['properties']
    geo_feature['id'] = tfeature['properties']['iso_a3']
    geo_feature['geometry'] = topojson.geometry(tfeature, topoJSON['arcs'], scale, translation)
    geoJSON['features'].append(geo_feature)

# %% [markdown]
# ### Get the longitude, latitude, and country name for each country

# %%
lons = []
lats = []
for k in range(len(geoJSON['features'])):
    country_coords = np.array(geoJSON['features'][k]['geometry']['coordinates'][0])
    m, M = country_coords[:,0].min(), country_coords[:,0].max()
    lons.append(0.5*(m+M))
    m, M = country_coords[:,1].min(), country_coords[:,1].max()
    lats.append(0.5*(m+M))
    
# Code to get country name and id lists and the total number of countries
countries = [geoJSON['features'][k]['properties']['name'] for k in range(len(geoJSON['features']))]
countries_df = pd.DataFrame (countries, columns = ['Country'])
country_ids = [geoJSON['features'][k]['id'] for k in range(len(geoJSON['features']))]
num_countries = len(geoJSON['features'])

# %% [markdown]
# ### Create Bivariate Choropleth Maps for each week

# %%
# Bivariate color codes: Blue = delta, Red = Omicron, Yellow = alpha
alp_del = ["#efefeb", "#dede97", "#caca3b", "#8597ef", "#7b8c99", "#70803c", "#002af5", "#00279d", "#00233d"]
del_omi = ["#efefeb", "#f0a390", "#f2340e", "#8597ef", "#856792", "#86210f", "#002af5", "#001c96", "#00090f"]

# %%
# Code to make maps by week
# Feeds data into map function after determining if alpha or delta is most prominent and creating comprehensive df
url_data = 'https://raw.githubusercontent.com/bryn-m/Covid_Evolution/main/tidy_variant_data.tsv'
variant_data = pd.read_csv(url_data, sep='\t')

variant_df = pd.DataFrame(variant_data)

# creating the bounds for assigning the bivariate colors
bound_list = np.array(variant_df[['Delta', 'Alpha', 'Omicron']].values.tolist())
bound_list = bound_list.flatten()
bound_list = bound_list[bound_list != 0.0]

bounds = np.percentile(bound_list, [33, 66])

# grouping the data by week
by_week_dfs = variant_data.groupby(by='Year_Week')
weeks = variant_data['Year_Week'].unique()

# determines the variant to display on the map with the delta variant based on the greatest average cases
# creates a dataframe with the country name, delta variant, and the second determined variant to then feed into the map creating function
# this is done for all weeks
for week in weeks:
    cur_week_df = by_week_dfs.get_group(week)

    delta = cur_week_df.loc[:,['Country', 'Delta']]
    temp_alpha = cur_week_df.loc[:, 'Alpha']
    temp_omicron = cur_week_df.loc[:, 'Omicron']
    if temp_alpha.mean() > temp_omicron.mean():
        alpha = cur_week_df.loc[:,['Country', 'Alpha']]
        complete_df = pd.merge(countries_df, alpha, on='Country', how='outer')
        color = alp_del
        var = 'Alpha'
    else:
        omicron = cur_week_df.loc[:, ['Country', 'Omicron']]
        complete_df = pd.merge(countries_df, omicron, on='Country', how='outer')
        color = del_omi
        var = 'Omicron'

    complete_df = pd.merge(complete_df, delta, on='Country', how='outer')
    complete_df.fillna(0, inplace=True)
    complete_df.set_index('Country', drop=True, inplace=True)

    generate_map(complete_df, color, var, countries, week, bounds)
# Out:
# Figure({
#     'data': [{'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [20.060906090609052, 20.10291029102909, 20.186918691869174,
#                     20.237323732373227, 20.346534653465334, 20.405340534053394,
#                     20.489348934893478, 20.52295229522951, 20.57335733573356,
#                     20.58175817581757, 20.564956495649554, 20.556555655565546,
#                     20.506150615061493, 20.5145514551455, 20.5145514551455,
#                     20.472547254725463, 20.447344734473432, 20.489348934893478,
#                     20.489348934893478, 20.489348934893478, 20.564956495649554,
#                     20.615361536153607, 20.657365736573645, 20.707770777077698,
#                     20.74137413741373, 20.867386738673858, 20.934593459345926,
#                     20.95979597959795, 20.968196819681957, 20.95979597959795,
#                     20.984998499849972, 21.027002700270017, 21.027002700270017,
#                     21.001800180017987, 20.95139513951394, 20.884188418841873,
#                     20.808580858085797, 20.766576657665752, 20.749774977497736,
#                     20.716171617161706, 20.69936993699369, 20.665766576657653,
#                     20.657365736573645, 20.606960696069592, 20.52295229522951,
#                     20.455745574557447, 20.405340534053394, 20.38013801380137,
#                     20.338133813381326, 20.312931293129303, 20.312931293129303,
#                     20.346534653465334, 20.38013801380137, 20.38013801380137,
#                     20.36333633363335, 20.304530453045295, 20.296129612961288,
#                     20.287728772877273, 20.270927092709258, 20.245724572457235,
#                     20.20372037203719, 20.128112811281113, 20.060906090609052,
#                     20.018901890189007, 20.00210021002099, 19.993699369936984,
#                     19.96849684968496, 19.85088508850884, 19.481248124812467,
#                     19.397239723972383, 19.363636363636353, 19.321632163216307,
#                     19.355235523552345, 19.397239723972383, 19.43924392439243,
#                     19.456045604560444, 19.43924392439243, 19.346834683468337,
#                     19.33843384338433, 19.380438043804368, 19.46444644464445,
#                     19.456045604560444, 19.481248124812467, 19.456045604560444,
#                     19.43924392439243, 19.49804980498049, 19.548454845484535,
#                     19.573657365736565, 19.573657365736565, 19.46444644464445,
#                     19.33843384338433, 19.346834683468337, 19.363636363636353,
#                     19.355235523552345, 19.363636363636353, 19.330033003300322,
#                     19.27962796279627, 19.330033003300322, 19.397239723972383,
#                     19.46444644464445, 19.548454845484535, 19.59885988598859,
#                     19.65766576657665, 19.699669966996687, 19.72487248724871,
#                     19.741674167416733, 19.741674167416733, 19.758475847584748,
#                     19.79207920792078, 19.859285928592847, 19.94329432943293,
#                     20.04410441044103, 20.060906090609052, None],
#               'y': [42.54623561965574, 42.52655779738133, 42.424233121554366,
#                     42.33765070354694, 42.31010175236276, 42.27468167226881,
#                     42.22351933435534, 42.172356996441856, 42.01493441824654,
#                     41.91654530687446, 41.87325409787075, 41.8614474045061,
#                     41.70796039076566, 41.625313537213124, 41.57415119929964,
#                     41.55447337702523, 41.52298886138617, 41.393115234375024,
#                     41.338017332006665, 41.27111273627365, 41.12943241589787,
#                     41.08220564243927, 41.06252782016485, 40.92871862869883,
#                     40.90510524196954, 40.916911935334184, 40.90510524196954,
#                     40.86968516187559, 40.85000733960118, 40.7752316149584,
#                     40.71619814813515, 40.65716468131191, 40.62174460121796,
#                     40.56271113439472, 40.495806538661704, 40.468257587477524,
#                     40.44464420074823, 40.39348186283475, 40.3344483960115,
#                     40.29115718700779, 40.24786597800408, 40.153412431086885,
#                     40.117992350992935, 40.08257227089899, 40.06683001307946,
#                     40.06683001307946, 40.05108775525993, 40.01566767516598,
#                     39.992054288436684, 39.980247595072036, 39.95269864388786,
#                     39.88972961260973, 39.84250283915113, 39.8031471946023,
#                     39.79134050123765, 39.79527606569253, 39.783469372327886,
#                     39.740178163324174, 39.70082251877534, 39.677209132046045,
#                     39.65359574531675, 39.66146687422651, 39.70082251877534,
#                     39.712629212139994, 39.70869364768511, 39.79921163014742,
#                     39.873987354790195, 40.04321662635016, 40.208510333455244,
#                     40.28328605809802, 40.34625508937615, 40.405288556199395,
#                     40.40922412065428, 40.39348186283475, 40.37380404056033,
#                     40.405288556199395, 40.47219315193241, 40.62174460121796,
#                     40.665035810221674, 40.790973872777926, 40.93265419315372,
#                     41.10581902916857, 41.23569265617971, 41.32227507418713,
#                     41.42459975001409, 41.562344505934995, 41.597764586028944,
#                     41.641055795032656, 41.786671679863325, 41.85751184005122,
#                     41.869318533415864, 41.920480871329346, 41.99919216042701,
#                     42.0228055471563, 42.0700323206149, 42.129065787438144,
#                     42.172356996441856, 42.25106828553952, 42.34158626800183,
#                     42.4163619926446, 42.49113771728738, 42.56591344193016,
#                     42.62888247320828, 42.648560295482696, 42.632818037663164,
#                     42.605269086478984, 42.52655779738133, 42.495073281742265,
#                     42.47539545946785, 42.487202152832495, 42.50687997510691,
#                     42.550171184110624, 42.54623561965574, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [20.615361536153607, 20.606960696069592, 20.52295229522951,
#                     20.489348934893478, 20.413741374137402, 20.396939693969387,
#                     20.430543054305417, 20.489348934893478, 20.57335733573356,
#                     20.615361536153607, None, 19.666066606660657,
#                     19.666066606660657, 19.63246324632462, 19.59885988598859,
#                     19.582058205820573, 19.540054005400528, 19.523252325232512,
#                     19.548454845484535, 19.63246324632462, 19.666066606660657,
#                     None, 19.993699369936984, 20.018901890189007,
#                     20.035703570357022, 20.086108610861075, 20.17011701170116,
#                     20.186918691869174, 20.237323732373227, 20.26252625262525,
#                     20.19531953195318, 20.153315331533143, 20.128112811281113,
#                     20.06930693069306, 20.04410441044103, 20.035703570357022,
#                     20.035703570357022, 19.800480048004786, 19.75007500750074,
#                     19.674467446744664, 19.682868286828672, 19.733273327332725,
#                     19.775277527752763, 19.78367836783677, 19.85088508850884,
#                     19.867686768676855, 19.867686768676855, 19.85088508850884,
#                     19.8088808880888, 19.78367836783677, 19.825682568256816,
#                     19.88448844884487, 19.94329432943293, 19.993699369936984, None],
#               'y': [60.039819621610604, 60.01620623488131, 60.012270670426425,
#                     60.03194849270084, 60.03194849270084, 60.039819621610604,
#                     60.0634330083399, 60.075239701704554, 60.07130413724967,
#                     60.039819621610604, None, 60.18543550644128, 60.16575768416686,
#                     60.16969324862174, 60.16182211971198, 60.1342731685278,
#                     60.146079861892446, 60.18543550644128, 60.24446897326452,
#                     60.24446897326452, 60.18543550644128, None, 60.35072921354636,
#                     60.35072921354636, 60.35860034245613, 60.35466477800124,
#                     60.315309133452416, 60.295631311178, 60.28382461781335,
#                     60.26021123108406, 60.19330663535104, 60.19330663535104,
#                     60.201177764260805, 60.19330663535104, 60.181499941986395,
#                     60.153950990802215, 60.094917523978964, 60.08311083061432,
#                     60.098853088433856, 60.23266227989987, 60.26808235999382,
#                     60.28382461781335, 60.28382461781335, 60.21298445762545,
#                     60.22085558653522, 60.26808235999382, 60.30350244008777,
#                     60.319244697907294, 60.33105139127195, 60.35466477800124,
#                     60.39008485809519, 60.405827115914725, 60.35860034245613,
#                     60.35072921354636, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [1.7050705070506993, 1.6798679867986728, 1.5874587458745815,
#                     1.5370537053705284, 1.486648664866479, 1.4530453045304448,
#                     1.4278427842784218, 1.4278427842784218, 1.4194419441944142,
#                     1.411041104110403, 1.4278427842784218, 1.461446144614456,
#                     1.5034503450344978, 1.5706570657065626, 1.713471347134707,
#                     1.73867386738673, 1.73867386738673, 1.713471347134707,
#                     1.7050705070506993, None],
#               'y': [42.50294441065203, 42.495073281742265, 42.45571763719343,
#                     42.4399753793739, 42.43603981491901, 42.43603981491901,
#                     42.459653201648315, 42.49900884619714, 42.53049336183621,
#                     42.550171184110624, 42.59739795756922, 42.621011344298516,
#                     42.64462473102782, 42.63675360211805, 42.605269086478984,
#                     42.577720135294804, 42.55804231302039, 42.52655779738133,
#                     42.50294441065203, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [45.549054905490536, 45.515451545154505, 45.48184818481846,
#                     45.48184818481846, 45.50705070507048, 45.53225322532252,
#                     45.56585658565855, 45.549054905490536, None, 46.48994899489948,
#                     46.32193219321931, 46.17071707170716, 46.11191119111909,
#                     46.07830783078306, 46.04470447044703, 45.95229522952293,
#                     45.977497749774955, 45.92709270927091, 45.80108010801078,
#                     45.76747674767475, 45.784278427842764, 45.79267926792677,
#                     45.784278427842764, 45.750675067506734, 45.68346834683467,
#                     45.60786078607859, 45.45664566456644, 45.347434743474324,
#                     45.28862886288627, 45.25502550255024, 45.17101710171015,
#                     45.15421542154213, 45.145814581458126, 45.1206120612061,
#                     45.078607860786065, 45.028202820282004, 44.868586858685845,
#                     44.76777677767775, 44.73417341734172, 44.55775577557755,
#                     44.39813981398139, 44.288928892889274, 44.17971797179716,
#                     44.003300330032985, 43.94449444944493, 43.79327932793278,
#                     43.66726672667265, 43.684068406840666, 43.70927092709269,
#                     43.67566756675666, 43.6084608460846, 43.616861686168605,
#                     43.59165916591658, 43.566456645664545, 43.66726672667265,
#                     43.70927092709269, 43.726072607260704, 43.692469246924674,
#                     43.63366336633662, 43.59165916591658, 43.5160516051605,
#                     43.457245724572445, 43.44044404440443, 43.490849084908476,
#                     43.64206420642063, 43.79327932793278, 43.9108910891089,
#                     44.07890789078907, 44.14611461146113, 44.230123012301206,
#                     44.47374737473746, 44.566156615661555, 44.84338433843382,
#                     44.85178517851783, 44.80978097809779, 44.80978097809779,
#                     44.97779777977796, 45.00300030002998, 45.019801980198,
#                     45.08700870087007, 45.15421542154213, 45.187818781878164,
#                     45.187818781878164, 45.07020702070206, 45.06180618061805,
#                     45.07020702070206, 45.10381038103809, 45.271827182718255,
#                     45.37263726372636, 45.42304230423041, 45.44824482448243,
#                     45.52385238523851, 45.591059105910574, 45.591059105910574,
#                     45.582658265826566, 45.397839783978384, 45.38103810381037,
#                     45.37263726372636, 45.45664566456644, 45.56585658565855,
#                     45.73387338733872, 45.96069606960694, 45.96909690969095,
#                     45.92709270927091, 45.901890189018886, 45.88508850885087,
#                     45.85988598859885, 45.63306330633061, 45.59945994599458,
#                     45.582658265826566, 45.582658265826566, 45.658265826582635,
#                     45.79267926792677, 45.85988598859885, 45.943894389438924,
#                     46.027902790279015, 46.095109510951076, 46.20432043204319,
#                     46.32193219321931, 46.48154815481547, 46.48994899489948,
#                     46.48154815481547, 46.380738073807365, 46.36393639363935,
#                     46.36393639363935, 46.380738073807365, 46.43954395439542,
#                     46.506750675067494, 46.58235823582356, 46.54875487548753,
#                     46.47314731473145, 46.4227422742274, 46.39753975397538,
#                     46.39753975397538, 46.47314731473145, 46.48994899489948,
#                     46.48994899489948, 46.48994899489948, None],
#               'y': [40.61780903676308, 40.59813121448866, 40.60600234339843,
#                     40.64929355240214, 40.665035810221674, 40.665035810221674,
#                     40.64929355240214, 40.61780903676308, None, 38.90583849888898,
#                     38.913709627798745, 38.87041841879503, 38.878289547704796,
#                     38.95306527234757, 39.0160343036257, 39.1773924462759,
#                     39.24429704200892, 39.283652686557744, 39.35055728229076,
#                     39.37810623347494, 39.417461878023765, 39.488302038211664,
#                     39.54733550503491, 39.56307776285444, 39.56307776285444,
#                     39.551271069489786, 39.49617316712143, 39.531593247215376,
#                     39.56701332730932, 39.5945622784935, 39.5709488917642,
#                     39.58275558512885, 39.65753130977163, 39.69688695432046,
#                     39.74411372777905, 39.76379155005347, 39.72050034104976,
#                     39.704758083230224, 39.74804929223394, 39.88579404815484,
#                     39.99598985289157, 40.03928106189528, 40.035345497440396,
#                     40.01566767516598, 40.02353880407575, 40.070765577534345,
#                     40.125863479902705, 40.149476866632, 40.16521912445153,
#                     40.23999484909431, 40.3580617827408, 40.39348186283475,
#                     40.44464420074823, 40.483999845297056, 40.574517827759365,
#                     40.64929355240214, 40.720133712590034, 40.79490943723281,
#                     40.92871862869883, 40.968074273247666, 41.00349435334161,
#                     41.06646338461974, 41.10581902916857, 41.113690158078334,
#                     41.11762572253322, 41.12943241589787, 41.16091693153693,
#                     41.18059475381135, 41.20420814054064, 41.212079269450406,
#                     41.192401447175996, 41.20814370499552, 41.212079269450406,
#                     41.219950398360176, 41.247499349544356, 41.259306042909,
#                     41.27898386518342, 41.29079055854807, 41.247499349544356,
#                     41.196337011630874, 41.176659189356464, 41.149110238172284,
#                     41.12549685144298, 41.10188346471369, 41.09007677134903,
#                     41.07433451352951, 41.07039894907462, 41.00742991779649,
#                     41.00349435334161, 40.98381653106719, 40.94839645097325,
#                     40.89723411305977, 40.84607177514629, 40.83032951732676,
#                     40.80278056614258, 40.708327019225386, 40.67290693913144,
#                     40.637486859037494, 40.53122661875565, 40.41709524956404,
#                     40.33051283155662, 40.232123720184546, 40.1730902533613,
#                     40.10618565762829, 40.05895888416969, 40.02353880407575,
#                     40.0117321107111, 40.01566767516598, 40.00386098180133,
#                     39.9881187239818, 39.97631203061715, 39.956634208342734,
#                     39.88185848369996, 39.80708275905718, 39.775598243418116,
#                     39.72050034104976, 39.6654024386814, 39.5945622784935,
#                     39.6181756652228, 39.55520663394467, 39.51191542494096,
#                     39.47649534484701, 39.4332041358433, 39.417461878023765,
#                     39.40171962020423, 39.38204179792982, 39.34662171783587,
#                     39.299394944377276, 39.2246192197345, 39.201005833005205,
#                     39.19707026855032, 39.20887696191497, 39.193134704095435,
#                     39.16952131736614, 39.110487850542896, 39.07113220599406,
#                     38.996356481351285, 38.90583849888898, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [16.952595259525943, 16.952595259525943, 16.944194419441935,
#                     ..., 16.92739273927392, 16.952595259525943, None],
#               'y': [48.59913375126577, 48.58732705790112, 48.55190697780718, ...,
#                     48.62274713799507, 48.59913375126577, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [46.11191119111909, 45.9186918691869, 45.57425742574256, ...,
#                     48.514551455145494, 48.57335733573356, None],
#               'y': [38.878289547704796, 38.90977406334386, 38.97274309462199, ...,
#                     41.77880055095356, 41.84570514668657, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [5.6954695469546905, 5.6954695469546905, 5.82988298829882,
#                     5.888688868886881, 5.997899789978987, 6.006300630062995,
#                     6.115511551155109, 6.157515751575147, 6.233123312331223,
#                     6.165916591659155, 6.182718271827177, 6.1995199519951925,
#                     6.291929192919284, 6.342334233423337, 6.342334233423337,
#                     6.36753675367536, 6.1743174317431695, 6.1239123912391165,
#                     6.115511551155109, 6.107110711071101, 6.090309030903079,
#                     6.056705670567048, 5.9726972697269645, 5.863486348634858,
#                     5.8214821482148125, 5.787878787878782, 5.7458745874587365,
#                     5.737473747374729, 5.737473747374729, 5.729072907290721,
#                     5.729072907290721, 5.787878787878782, 5.804680468046797,
#                     5.880288028802873, 5.85508550855085, 5.838283828382828,
#                     5.813081308130805, 5.787878787878782, 5.712271227122706,
#                     5.611461146114607, 5.5442544254425385, 5.510651065106501,
#                     5.435043504350425, 5.351035103510341, 5.300630063006295,
#                     5.275427542754265, 5.216621662166212, 5.124212421242113,
#                     5.057005700570052, 5.006600660065999, 4.930993099309923,
#                     4.863786378637855, 4.846984698469839, 4.838583858385832,
#                     4.788178817881779, 4.863786378637855, 4.821782178217816,
#                     4.771377137713763, 4.704170417041695, 4.678967896789672,
#                     4.653765376537649, 4.544554455445535, 4.36813681368136,
#                     4.17491749174917, 4.14971497149714, 4.132913291329125,
#                     4.132913291329125, 4.14971497149714, 4.183318331833178,
#                     4.191719171917185, 4.158115811581148, 4.132913291329125,
#                     4.141314131413132, 4.166516651665155, 4.17491749174917,
#                     4.040504050405033, 3.948094809480942, 3.8556855685568507,
#                     3.7884788478847824, 3.746474647464737, 3.721272127212714,
#                     3.6876687668766834, 3.670867086708661, 3.6288628862886227,
#                     3.595259525952585, 3.4776477647764708, 3.318031803180311,
#                     3.2760276027602657, 3.2508250825082428, 3.2340234023402274,
#                     3.1836183618361744, 3.1584158415841515, 3.1080108010800984,
#                     3.0240024002400148, 2.923192319231916, 2.8643864386438587,
#                     2.839183918391832, 2.763576357635756, 2.671167116711665,
#                     2.595559555955589, 2.57875787578757, 2.6039603960395965,
#                     2.57875787578757, 2.536753675367528, 2.5283528352835205,
#                     2.95679567956795, 3.22562256225622, 3.3516351635163417,
#                     3.376837683768372, 3.4020402040203948, 3.4356435643564254,
#                     3.469246924692463, 3.519651965196509, 3.5784578457845697,
#                     3.6792679267926687, 3.7548754875487447, 3.7800780078007747,
#                     3.8304830483048207, 3.9060906090608967, 4.040504050405033,
#                     4.17491749174917, 4.208520852085201, 4.225322532253216,
#                     4.300930093009292, 4.376537653765368, 4.401740174017391,
#                     4.384938493849376, 4.443744374437436, 4.502550255025497,
#                     4.52775277527752, 4.586558655865581, 4.636963696369627,
#                     4.754575457545748, 4.788178817881779, 4.813381338133809,
#                     4.813381338133809, 4.821782178217816, 4.846984698469839,
#                     4.947794779477938, 4.989798979897984, 5.031803180318022,
#                     5.057005700570052, 5.073807380738067, 5.09900990099009,
#                     5.216621662166212, 5.309030903090303, 5.426642664266417,
#                     5.47704770477047, 5.510651065106501, 5.5442544254425385,
#                     5.611461146114607, 5.754275427542744, 5.7962796279627895,
#                     5.82988298829882, 5.8214821482148125, 5.7458745874587365,
#                     5.737473747374729, 5.7458745874587365, 5.737473747374729,
#                     5.6450645064506375, 5.63666366636663, 5.6702670267026605,
#                     5.6954695469546905, None],
#               'y': [50.77550089481606, 50.77943645927094, 50.810920974910005,
#                     50.75188750808677, 50.75188750808677, 50.73220968581235,
#                     50.68104734789887, 50.637756138895156, 50.59840049434632,
#                     50.54723815643285, 50.523624769703545, 50.50001138297425,
#                     50.484269125154725, 50.45278460951566, 50.40162227160218,
#                     50.315039853594755, 50.23239300004221, 50.137939453125014,
#                     50.12219719530549, 50.12219719530549, 50.153681710944554,
#                     50.153681710944554, 50.1654884043092, 50.082841550756655,
#                     50.01200139056876, 49.96083905265529, 49.921483408106454,
#                     49.87425663464786, 49.858514376828325, 49.83490099009903,
#                     49.80735203891484, 49.76012526545625, 49.732576314272066,
#                     49.64599389626464, 49.61450938062558, 49.579089300531635,
#                     49.55547591380234, 49.5397336559828, 49.5397336559828,
#                     49.52792696261815, 49.51218470479863, 49.51218470479863,
#                     49.55547591380234, 49.61844494508046, 49.64992946071953,
#                     49.67747841190371, 49.689285105268354, 49.72076962090742,
#                     49.75618970100137, 49.77980308773067, 49.78767421664043,
#                     49.78767421664043, 49.84670768346368, 49.913612279196684,
#                     49.96083905265529, 50.13400388867014, 50.153681710944554,
#                     50.137939453125014, 50.09858380857619, 50.04742147066271,
#                     50.004130261659, 49.96083905265529, 49.94509679483575,
#                     49.96083905265529, 49.972645746019936, 49.98445243938458,
#                     50.00019469720411, 50.02380808393341, 50.05135703511759,
#                     50.0946482441213, 50.13006832421525, 50.1418750175799,
#                     50.17729509767385, 50.22058630667756, 50.24813525786174,
#                     50.32291098250452, 50.33471767586917, 50.33865324032405,
#                     50.34652436923382, 50.34258880477893, 50.32291098250452,
#                     50.307168724684985, 50.32291098250452, 50.45672017397054,
#                     50.476397996244955, 50.50001138297425, 50.50788251188402,
#                     50.531495898613315, 50.59052936543656, 50.66136952562445,
#                     50.73220968581235, 50.747951943631875, 50.77943645927094,
#                     50.76762976590629, 50.728274121357465, 50.71646742799281,
#                     50.71253186353793, 50.75188750808677, 50.810920974910005,
#                     50.87782557064302, 50.91324565073697, 50.95653685974068,
#                     50.988021375379745, 51.050990406657874, 51.098217180116464,
#                     51.26351088722155, 51.35009330522898, 51.377642256413154,
#                     51.29105983840573, 51.26351088722155, 51.24383306494714,
#                     51.24383306494714, 51.26351088722155, 51.28712427395085,
#                     51.275317580586204, 51.25563975831179, 51.232026371582485,
#                     51.212348549308075, 51.20841298485319, 51.24776862940202,
#                     51.30680209622526, 51.35009330522898, 51.38551338532292,
#                     51.36189999859363, 51.357964434138744, 51.365835563048506,
#                     51.428804594326635, 51.4602891099657, 51.47603136778523,
#                     51.44848241660105, 51.420933465416866, 51.420933465416866,
#                     51.491773625604765, 51.47603136778523, 51.45241798105593,
#                     51.43274015878152, 51.4130623365071, 51.40519120759734,
#                     51.40912677205222, 51.44454685214617, 51.46816023887547,
#                     51.45241798105593, 51.40519120759734, 51.34615774077409,
#                     51.27925314504108, 51.259575322766665, 51.27138201613131,
#                     51.28318870949597, 51.275317580586204, 51.23989750049225,
#                     51.196606291488536, 51.16905734030436, 51.15331508248482,
#                     51.12576613130065, 51.08641048675182, 50.988021375379745,
#                     50.96047242419556, 50.94866573083091, 50.93292347301138,
#                     50.866018877278364, 50.84240549054907, 50.80698541045513,
#                     50.77550089481606, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [28.587758775877575, 28.56255625562555, 28.461746174617446,
#                     28.31893189318931, 28.13411341134112, 28.03330333033302,
#                     27.982898289828967, 27.93249324932492, 27.898889888988883,
#                     27.890489048904875, 27.8148814881488, 27.756075607560746,
#                     27.487248724872472, 27.638463846384624, 27.705670567056693,
#                     27.823282328232807, 27.982898289828967, 28.016501650165004,
#                     27.882088208820868, 27.83168316831682, 27.798079807980784,
#                     27.739273927392723, 27.663666366636647, 27.579657965796564,
#                     27.537653765376525, 27.478847884788465, 27.36123612361235,
#                     27.294029402940282, 27.24362436243623, 27.193219321932183,
#                     27.008400840083993, 26.966396639663955, 26.88238823882387,
#                     26.798379837983788, 26.680768076807666, 26.613561356135598,
#                     26.579957995799568, 26.546354635463537, 26.529552955295514,
#                     26.5127512751275, 26.361536153615347, 26.327932793279317,
#                     26.31953195319531, 26.31953195319531, 26.201920192019188,
#                     26.109510951095096, 26.084308430843073, 26.067506750675058,
#                     26.075907590759066, 26.109510951095096, 26.143114311431127,
#                     26.15151515151514, 26.13471347134712, 26.067506750675058,
#                     25.924692469246914, 25.78187818781877, 25.72307230723071,
#                     25.62226222622261, 25.52985298529852, 25.378637863786366,
#                     25.252625262526237, 25.135013501350123, 24.99219921992198,
#                     24.849384938493834, 24.79897989798979, 24.77377737773776,
#                     24.647764776477636, 24.597359735973583, 24.57215721572156,
#                     24.521752175217507, 24.488148814881477, 24.387338733873378,
#                     24.28652865286527, 24.227722772277218, 24.05970597059705,
#                     24.03450345034502, 24.009300930092998, 23.97569756975696,
#                     23.88328832883287, 23.765676567656755, 23.631263126312618,
#                     23.538853885388527, 23.42964296429642, 23.37083708370836,
#                     23.236423642364223, 23.15241524152414, 23.026402640264017,
#                     22.917191719171903, 22.92559255925591, 22.95079507950794,
#                     23.009600960095995, 23.001200120011987, 22.99279927992798,
#                     22.942394239423933, 22.908790879087896, 22.83318331833182,
#                     22.79957995799579, 22.681968196819668, 22.58115811581157,
#                     22.497149714971485, 22.345934593459333, 22.42154215421541,
#                     22.446744674467432, 22.522352235223508, 22.530753075307516,
#                     22.522352235223508, 22.471947194719462, 22.438343834383424,
#                     22.463546354635454, 22.463546354635454, 22.438343834383424,
#                     22.463546354635454, 22.522352235223508, 22.555955595559546,
#                     22.707170717071698, 22.79957995799579, 22.85838583858385,
#                     22.917191719171903, 22.942394239423933, 22.967596759675956,
#                     22.975997599759964, 22.85838583858385, 22.816381638163804,
#                     22.76597659765975, 22.69876987698769, 22.555955595559546,
#                     22.497149714971485, 22.471947194719462, 22.438343834383424,
#                     22.396339633963386, 22.38793879387938, 22.371137113711356,
#                     22.36273627362735, 22.396339633963386, 22.42154215421541,
#                     22.471947194719462, 22.597959795979584, 22.60636063606359,
#                     22.623162316231614, 22.665166516651652, 22.707170717071698,
#                     22.77437743774376, 22.942394239423933, 23.026402640264017,
#                     23.026402640264017, 22.98439843984397, 22.908790879087896,
#                     22.866786678667857, 22.85838583858385, 22.866786678667857,
#                     22.917191719171903, 23.228022802280215, 23.53045304530452,
#                     23.950495049504937, 24.227722772277218, 24.429342934293416,
#                     24.807380738073796, 25.160216021602146, 25.49624962496248,
#                     25.689468946894678, 25.8154815481548, 25.93309330933092,
#                     26.218721872187203, 26.487548754875476, 26.848784878487834,
#                     27.08400840084007, 27.117611761176107, 27.42844284428442,
#                     27.56285628562855, 27.672067206720662, 27.7140714071407,
#                     27.739273927392723, 27.882088208820868, 27.949294929492936,
#                     28.050105010501035, 28.218121812181202, 28.377737773777362,
#                     28.419741974197407, 28.587758775877575, None],
#               'y': [43.74264721394017, 43.502577782192304, 43.3884464130007,
#                     43.42780205754953, 43.39631754191046, 43.26644391489933,
#                     43.23102383480538, 43.187732625801665, 43.02243891869658,
#                     42.75088497130966, 42.71546489121571, 42.70759376230594,
#                     42.46752433055808, 42.40061973482507, 42.34945739691159,
#                     42.207777076535805, 42.046418933885604, 41.96770764478794,
#                     41.98738546706235, 41.97951433815259, 41.95590095142329,
#                     41.95983651587817, 41.95983651587817, 41.93228756469399,
#                     41.920480871329346, 41.948029822513526, 42.02674111161119,
#                     42.07790344952467, 42.093645707344194, 42.07790344952467,
#                     42.05822562725025, 42.02674111161119, 41.99132103151724,
#                     41.975578773697706, 41.96377208033306, 41.96377208033306,
#                     41.948029822513526, 41.89686748460005, 41.84570514668657,
#                     41.82602732441215, 41.80241393768286, 41.77092942204379,
#                     41.74338047085961, 41.71583151967543, 41.74338047085961,
#                     41.72763821304008, 41.704024826310786, 41.67254031067172,
#                     41.641055795032656, 41.60957127939359, 41.52298886138617,
#                     41.436406443378736, 41.38524410546526, 41.34982402537131,
#                     41.310468380822485, 41.3301462030969, 41.31440394527736,
#                     41.310468380822485, 41.29866168745784, 41.26324160736389,
#                     41.24356378508947, 41.31440394527736, 41.365566283190844,
#                     41.393115234375024, 41.373437412100614, 41.357695154281075,
#                     41.420664185559204, 41.444277572288506, 41.4678909590178,
#                     41.55447337702523, 41.55447337702523, 41.52298886138617,
#                     41.526924425841045, 41.53085999029593, 41.526924425841045,
#                     41.4678909590178, 41.46001983010804, 41.45214870119827,
#                     41.45608426565315, 41.41279305664944, 41.38524410546526,
#                     41.38524410546526, 41.39705079882991, 41.38917966992014,
#                     41.38524410546526, 41.32227507418713, 41.32621063864202,
#                     41.338017332006665, 41.357695154281075, 41.60563571493871,
#                     41.71583151967543, 41.73944490640473, 41.759122728679145,
#                     41.77486498649868, 41.83389845332192, 41.99525659597212,
#                     42.02674111161119, 42.05822562725025, 42.10545240070884,
#                     42.16448586753209, 42.31403731681765, 42.32977957463717,
#                     42.35732852582136, 42.4399753793739, 42.479331023922725,
#                     42.50294441065203, 42.542300055200855, 42.62888247320828,
#                     42.70759376230594, 42.75088497130966, 42.79024061585849,
#                     42.84140295377196, 42.86895190495615, 42.87682303386591,
#                     42.88469416277567, 42.98701883860264, 43.0185033542417,
#                     43.07753682106494, 43.097214643339356, 43.14050585234307,
#                     43.187732625801665, 43.250701657079794, 43.30186399499327,
#                     43.35302633290675, 43.392381977455585, 43.45535100873371,
#                     43.51832004001184, 43.600966893564376, 43.663935924842505,
#                     43.70722713384622, 43.73871164948528, 43.782002858488994,
#                     43.860714147586656, 43.97090995232338, 44.006330032417324,
#                     44.01813672578198, 44.07717019260522, 44.148010352793115,
#                     44.19523712625171, 44.21885051298101, 44.238528335255424,
#                     44.19523712625171, 44.1283325305187, 44.07717019260522,
#                     44.04568567696616, 44.01813672578198, 43.986652210142914,
#                     43.94729656559409, 43.90006979213548, 43.86464971204154,
#                     43.833165196402476, 43.87252084095131, 43.85284301867689,
#                     43.78593842294388, 43.762325036214584, 43.79380955185365,
#                     43.73871164948528, 43.68754931157181, 43.671807053752275,
#                     43.7111626983011, 43.76626060066947, 43.87252084095131,
#                     44.006330032417324, 44.085041321514986, 44.148010352793115,
#                     44.16768817506753, 44.148010352793115, 44.02207229023686,
#                     44.01813672578198, 43.99845890350756, 43.96303882341361,
#                     43.95516769450385, 43.986652210142914, 43.9197476144099,
#                     43.82135850303783, 43.77413172957923, 43.74658277839505,
#                     43.73871164948528, 43.74264721394017, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [19.010801080108003, 19.044404440444033, 19.128412841284117,
#                     19.237623762376224, 19.3132313231323, 19.346834683468337,
#                     19.355235523552345, 19.33843384338433, 19.288028802880277,
#                     19.22082208220821, 19.15361536153614, 19.128412841284117,
#                     19.128412841284117, 19.12001200120011, 19.128412841284117,
#                     19.15361536153614, 19.229222922292216, 19.33843384338433,
#                     19.43084308430842, 19.548454845484535, 19.582058205820573,
#                     19.582058205820573, 19.548454845484535, 19.447644764476436,
#                     19.346834683468337, 19.304830483048292, 19.27122712271226,
#                     19.24602460246024, 19.254425442544246, 19.363636363636353,
#                     19.48964896489648, 19.49804980498049, 19.481248124812467,
#                     19.447644764476436, 19.397239723972383, 19.363636363636353,
#                     19.304830483048292, 19.254425442544246, 19.195619561956185,
#                     19.162016201620148, 19.1116111611161, 19.078007800780064,
#                     19.027602760276018, 18.977197719771965, 18.951995199519942,
#                     18.943594359435934, 18.977197719771965, 19.036003600360026,
#                     19.027602760276018, 18.977197719771965, 18.935193519351927,
#                     18.89318931893188, 18.851185118511843, 18.750375037503737,
#                     18.67476747674766, 18.657965796579646, 18.632763276327623,
#                     18.624362436243615, 18.624362436243615, 18.48994899489948,
#                     18.456345634563448, 18.44794479447944, 18.456345634563448,
#                     18.464746474647455, 18.54035403540353, 18.54875487548754,
#                     18.531953195319524, 18.48154815481547, 18.456345634563448,
#                     18.439543954395425, 18.347134713471334, 18.305130513051296,
#                     18.120312031203106, 18.044704470447037, 17.918691869186908,
#                     17.843084308430832, 17.801080108010787, 17.742274227422733,
#                     17.666666666666657, 17.582658265826574, 17.641464146414627,
#                     17.65826582658265, 17.649864986498642, 17.624662466246612,
#                     17.4062406240624, 17.297029702970285, 17.271827182718262,
#                     17.271827182718262, 17.24662466246624, 17.08700870087008,
#                     16.90219021902189, 16.717371737173707, 16.683768376837676,
#                     16.591359135913578, 16.473747374737464, 16.381338133813372,
#                     16.29732973297329, 16.213321332133205, 16.17131713171316,
#                     16.12931293129312, 16.10411041104109, 16.045304530453038,
#                     15.87728772877287, 15.734473447344726, 15.734473447344726,
#                     15.759675967596749, 15.784878487848772, 15.826882688268817,
#                     15.885688568856878, 15.961296129612954, 16.028502850285015,
#                     16.154515451545144, 16.23012301230122, 16.29732973297329,
#                     16.364536453645357, 16.45694569456945, 16.532553255325524,
#                     16.792979297929783, 16.918991899189905, 17.129012901290118,
#                     17.2130213021302, 17.255025502550247, 17.322232223222315,
#                     17.465046504650452, 17.49864986498649, 17.549054905490536,
#                     17.649864986498642, 17.69186918691868, 17.8094809480948,
#                     17.876687668766863, 17.95229522952294, 17.994299429942984,
#                     18.13711371137113, 18.221122112211212, 18.28832883288328,
#                     18.35553555355534, 18.42274227422741, 18.48994899489948,
#                     18.666366636663653, 18.74197419741973, 18.775577557755767,
#                     18.783978397839775, 18.792379237923782, 18.83438343834382,
#                     18.943594359435934, 19.010801080108003, None],
#               'y': [44.8682186480367, 44.87215421249158, 44.89970316367577,
#                     44.9154454214953, 44.89576759922088, 44.88002534140135,
#                     44.86034751912693, 44.78163623002928, 44.695053812021854,
#                     44.60847139401442, 44.52582454046188, 44.48253333145817,
#                     44.41562873572516, 44.3605308333568, 44.32904631771773,
#                     44.30149736653355, 44.281819544259136, 44.22672164189078,
#                     44.15588148170288, 44.07323462815034, 44.041750112511274,
#                     44.01026559687221, 43.986652210142914, 43.978781081233144,
#                     43.986652210142914, 43.99452333905268, 43.98271664568803,
#                     43.9669743878685, 43.9433610011392, 43.84497188976712,
#                     43.70329156939134, 43.644258102568095, 43.5970313291095,
#                     43.56161124901555, 43.56948237792532, 43.59309576465461,
#                     43.59309576465461, 43.58522463574485, 43.53406229783137,
#                     43.53406229783137, 43.5261911689216, 43.51832004001184,
#                     43.53406229783137, 43.54193342674114, 43.5261911689216,
#                     43.49864221773743, 43.44354431536906, 43.356961897361636,
#                     43.29399286608351, 43.286121737173744, 43.3412196395421,
#                     43.34909076845187, 43.34515520399699, 43.28218617271886,
#                     43.23102383480538, 43.195603754711435, 43.152312545707716,
#                     43.12476359452354, 43.026374483151464, 43.01063222533193,
#                     42.998825531967285, 42.96734101632822, 42.845338518226846,
#                     42.77843392249383, 42.67610924666688, 42.64068916657293,
#                     42.621011344298516, 42.577720135294804, 42.56591344193016,
#                     42.55804231302039, 42.58559126420457, 42.601333522024106,
#                     42.69185150448641, 42.74301384239989, 42.80598287367802,
#                     42.845338518226846, 42.90043642059521, 42.91617867841474,
#                     42.89650085614033, 42.93979206514404, 42.95946988741845,
#                     42.97914770969287, 43.00669666087705, 43.042116740971,
#                     43.19953931916632, 43.305799559448154, 43.34515520399699,
#                     43.447479879823945, 43.47109326655324, 43.51832004001184,
#                     43.64819366702298, 43.778067294034116, 43.81348737412806,
#                     43.91187648550014, 44.002394467962446, 44.06142793478569,
#                     44.12439696606381, 44.21491494852613, 44.35265970444703,
#                     44.4746622025484, 44.521888976007, 44.53763123382653,
#                     44.6832471186572, 44.765893972209746, 44.856411954672055,
#                     45.00596340395761, 45.17912823997246, 45.20274162670175,
#                     45.214548320066406, 45.21061275561152, 45.190934933337104,
#                     45.072867999690615, 45.02564122623202, 45.009898968412486,
#                     45.05712574187108, 45.163385982152924, 45.21848388452129,
#                     45.198806062246874, 45.27751735134453, 45.17125711106269,
#                     45.15551485324316, 45.17125711106269, 45.163385982152924,
#                     45.13190146651386, 45.12009477314921, 45.1240303376041,
#                     45.163385982152924, 45.15945041769804, 45.0768035641455,
#                     45.0768035641455, 45.11222364423945, 45.143708159878514,
#                     45.12009477314921, 45.13190146651386, 45.135837030968744,
#                     45.12009477314921, 45.100416950874795, 45.08467469305526,
#                     45.0768035641455, 45.02564122623202, 44.97841445277342,
#                     44.94692993713436, 44.9154454214953, 44.883960905856235,
#                     44.86428308358182, 44.8682186480367, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [28.15091509150914, 28.28532853285327, 28.31893189318931, ...,
#                     28.117311731173103, 28.15091509150914, None],
#               'y': [56.14361081127645, 56.05702839326902, 56.053092828814144, ...,
#                     56.14754637573134, 56.14361081127645, None]},
#              {'fill': 'toself',
#               'fillcolor': '#efefeb',
#               'hoverinfo': 'none',
#               'line': {'color': 'rgb(150,150,150)', 'width': 1},
#               'mode': 'lines',
#               'opacity': 0.95,
#               'type': 'scatter',
#               'x': [9.526252625262515, 9.551455145514545, 9.627062706270621,
#                     9.610261026102599, 9.526252625262515, 9.484248424842477,
#                     9.475847584758469, 9.484248424842477, 9.501050105010492,
#                     9.576657665766568, 9.618661866186606, 9.744674467446735,
#                     9.845484548454834, 9.862286228622857, 9.879087908790872,
#                     9.996699669966986, 10.131113111311123, 10.181518151815169,
#                     10.349534953495343, 10.416741674167405, 10.45874587458745,
#                     10.450345034503442, 10.408340834083397, 10.39993999399939,
#                     10.441944194419435, 10.441944194419435, 10.433543354335427,
#                     10.366336633663359, 10.273927392739267, 10.198319831983191,
#                     10.13951395139513, 10.089108910891078, 10.063906390639055,
#                     10.038703870387032, 10.04710471047104, 10.08070807080707,
#                     10.1059105910591, 10.131113111311123, 10.147914791479138,
#                     10.131113111311123, 10.08070807080707, 10.038703870387032,
#                     9.971497149714963, 9.937893789378926, 9.88748874887488,
#                     9.78667866786678, 9.635463546354629, 9.576657665766568,
#                     9.526252625262515, 9.484248424842477, 9.442244224422431,
#                     9.425442544254416, 9.400240024002393, 9.307830783078302,
#                     9.257425742574249, 9.257425742574249, 9.249024902490241,
#                     9.207020702070196, 9.072607260726066, 9.022202220222013,
#                     9.005400540053998, 8.99699969996999, 9.022202220222013,
#                     9.047404740474036, 9.022202220222013, 8.954995499549945,
#                     8.904590459045899, 8.887788778877876, 8.77857785778577,
# ...
#                     49.22488849959217, 49.25637301523123, 49.33508430432889,
#                     49.362633255513074, 49.39018220669725, 49.42166672233631,
#                     49.464957931340024, 49.49250688252421, 49.488571318069326,
#                     49.49250688252421, 49.508249140343736, 49.51218470479863,
#                     49.49644244697909, 49.4492156735205, 49.39805333560702,
#                     49.39805333560702, 49.51218470479863, 49.523991398163275,
#                     49.5633470427121, 49.59876712280605, 49.57515373607675,
#                     49.50431357588886, 49.44528010906561, 49.4256022867912,
#                     49.40592446451679, 49.39411777115213, 49.39018220669725,
#                     49.37050438442283, 49.319342046509355, 49.26817970859588,
#                     49.236695192956816, 49.20521067731775, 49.193403983953104,
#                     49.20521067731775, 49.22095293513728, 49.181597290588456,
#                     49.27211527305076, 49.31540648205447, 49.33901986878377,
#                     49.36656881996795, 49.38624664224237, 49.382311077787485,
#                     49.39411777115213, 49.39018220669725, 49.382311077787485,
#                     49.39018220669725, 49.37050438442283, 49.32721317541912,
#                     49.31540648205447, 49.31540648205447, 49.33901986878377,
#                     49.417731157881434, 49.417731157881434, 49.42953785124608,
#                     49.42953785124608, 49.41379559342655, 49.382311077787485,
#                     49.34295543323866, 49.299664224234945, 49.24456632186658,
#                     49.20914624177263, 49.15404833940427, 49.08320817921638,
#                     49.07140148585172, None]},
#              {'hoverinfo': 'text',
#               'marker': {'color': [#efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #dede97, #efefeb, #efefeb, #efefeb,
#                                    #efefeb, #efefeb, #efefeb],
#                          'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [Albania<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Aland<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Andorra<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Armenia<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Austria<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Azerbaijan<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Belgium<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Bulgaria<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Bosnia and
#                        Herz.<br>Delta Cases Percent: 0.0000<br>Alpha Cases Percent:
#                        0.0000, Belarus<br>Delta Cases Percent: 0.0000<br>Alpha
#                        Cases Percent: 0.0000, Switzerland<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, N. Cyprus<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Cyprus<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Czech Rep.<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Germany<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Denmark<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Spain<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Estonia<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Finland<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, France<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Faeroe Is.<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000, United
#                        Kingdom<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Georgia<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Guernsey<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Greece<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Greenland<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Croatia<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Hungary<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Isle of Man<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Ireland<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Iceland<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Italy<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0905, Jersey<br>Delta Cases
#                        Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Kazakhstan<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Kosovo<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000,
#                        Liechtenstein<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Lithuania<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Luxembourg<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Latvia<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Monaco<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Moldova<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Macedonia<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Montenegro<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Netherlands<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Norway<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Poland<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Portugal<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Romania<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Russia<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, San Marino<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Serbia<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Slovakia<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 76.8065, Slovenia<br>Delta
#                        Cases Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Sweden<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Turkmenistan<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000, Turkey<br>Delta Cases
#                        Percent: 0.0000<br>Alpha Cases Percent: 0.0000,
#                        Ukraine<br>Delta Cases Percent: 0.0000<br>Alpha Cases
#                        Percent: 0.0000, Vatican<br>Delta Cases Percent:
#                        0.0000<br>Alpha Cases Percent: 0.0000],
#               'type': 'scatter',
#               'x': [20.153315331533143, 40.32759057888211, 1.5748574857485664,
#                     43.08343197112681, 13.336033603360324, 42.495100369411944,
#                     4.44794479447944, 25.466846684668454, 17.65826582658265,
#                     27.945094509450932, 8.215721572157207, 33.63246324632462,
#                     33.17461746174616, 15.461446144614449, 34.041387974246646,
#                     33.12486853910001, 20.134749891004738, 40.61888894700017,
#                     40.86929370183112, 26.145115649260248, 27.374523277523068,
#                     24.81085587806828, 43.32703270327031, -2.5793579357935865,
#                     29.693340147002992, 22.746006187532814, 30.189211789831333,
#                     19.485448544854474, -4.561956195619567, 21.982625537944422,
#                     -19.015601560156018, 24.405962898535957, -2.1215121512151285,
#                     47.521365293267614, 20.888388838883877, 9.543054305430534,
#                     38.118791305400066, 6.111311131113105, 24.6099609960996,
#                     7.409240924092401, 28.377737773777362, 21.728472847284714,
#                     19.39303930393038, 27.80541795878807, 32.69482311268236,
#                     19.115811581158106, 7.840131891607143, 24.975397539753963,
#                     46.73766818088059, 12.45814581458145, 20.909390939093896,
#                     19.69966996699669, 14.948994899489936, 36.41088997571632,
#                     45.956662402080056, 33.05218342146715, 39.108838264197516,
#                     12.432943294329423],
#               'y': [41.15107802039972, 40.31158346547545, 42.540332272973416,
#                     43.05679137982158, 47.69985727332501, 42.41423296626538,
#                     50.501979165201696, 42.74104606017245, 43.91777983218246,
#                     53.70552863147644, 46.80254857761169, 35.332345973855226,
#                     34.8758204970888, 49.80735203891484, 34.022353656264066,
#                     33.185793264385026, 20.114277501968957, 40.642918251786114,
#                     40.81915351691419, 26.05550602667689, 27.367181859787543,
#                     24.753109419828707, 42.31994066349997, 49.46889349579491,
#                     29.72300794288414, 22.733291134289207, 30.220998430409455,
#                     47.15281381409628, 54.23289426843076, 21.964650642310332,
#                     64.96714631912411, 24.374857031601607, 49.21898515290984,
#                     47.48882135528006, 42.558042313020394, 47.162652725233485,
#                     38.093323929560924, 49.805384256687404, 56.86578688874748,
#                     43.75051834284993, 46.96390672026189, 41.60366793271127,
#                     42.7056259800785, 27.77930707865709, 32.63999006590112,
#                     51.92862128009678, 7.881757443322474, 45.9682089131765,
#                     46.719428429659374, 43.941393218911756, 44.20704381961636,
#                     48.681780604818314, 46.14530931364623, 36.357873648692994,
#                     45.92884859530876, 32.923029822513506, 39.15243159814028,
#                     41.90080304905493]},
#              {'colorscale': [[0.0, '#efefeb'], [0.11, '#efefeb'], [0.11,
#                              '#dede97'], [0.22, '#dede97'], [0.22, '#caca3b'],
#                              [0.33, '#caca3b'], [0.33, '#8597ef'], [0.44,
#                              '#8597ef'], [0.44, '#7b8c99'], [0.56, '#7b8c99'],
#                              [0.56, '#70803c'], [0.67, '#70803c'], [0.67,
#                              '#002af5'], [0.78, '#002af5'], [0.78, '#00279d'],
#                              [0.89, '#00279d'], [0.89, '#00233d'], [1.0,
#                              '#00233d']],
#               'hoverinfo': 'text',
#               'showscale': False,
#               'text': [['Alpha < P_33<br>Delta < P_33', 'P_33 <= Alpha <= P_66
#                        <br>Delta < P_33', 'Alpha > P_66<br>Delta < P_33'], ['Alpha
#                        < P_33<br>P_33 <= Delta <= P_66 ', 'P_33 <= Alpha <= P_66
#                        <br>P_33 <= Delta <= P_66 ', 'Alpha > P_66<br>P_33 <= Delta
#                        <= P_66 '], ['Alpha < P_33<br>Delta > P_66', 'P_33 <= Alpha
#                        <= P_66 <br>Delta > P_66', 'Alpha > P_66<br>Delta > P_66']],
#               'type': 'heatmap',
#               'x': [0, 1, 2],
#               'xaxis': 'x2',
#               'y': [0, 1, 2],
#               'yaxis': 'y2',
#               'z': [[0, 1, 2], [3, 4, 5], [6, 7, 8]]}],
#     'layout': {'dragmode': 'select',
#                'font': {'family': 'Balto'},
#                'height': 850,
#                'hovermode': 'closest',
#                'showlegend': False,
#                'template': '...',
#                'title': {'text': ('Covid Variants Bivariate Choro' ... 'd 66th percentiles of the data')},
#                'width': 1100,
#                'xaxis': {'autorange': False,
#                          'domain': [0, 1],
#                          'fixedrange': True,
#                          'range': [-29.1, 55],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'ticks': '',
#                          'zeroline': False},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.065, 0.25],
#                           'showgrid': False,
#                           'showline': False,
#                           'showticklabels': False,
#                           'side': 'bottom',
#                           'ticks': '',
#                           'title': {'font': {'size': 12}, 'text': '    7.951      118.668<br>Alpha Cases Per 100,000'},
#                           'zeroline': False},
#                'yaxis': {'autorange': False,
#                          'domain': [0, 1],
#                          'fixedrange': True,
#                          'range': [34, 72.1],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'ticks': '',
#                          'zeroline': False},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.61, 0.75],
#                           'showgrid': False,
#                           'showline': False,
#                           'showticklabels': False,
#                           'side': 'left',
#                           'ticks': '',
#                           'title': {'font': {'size': 12}, 'text': 'Delta Cases Per 100,000<br> 7.951    118.668'},
#                           'zeroline': False}}
# })
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21212/291454533.py in <module>
#      41     complete_df.set_index('Country', drop=True, inplace=True)
#      42
# ---> 43     generate_map(complete_df, color, var, countries, week, bounds)
#
# ~\AppData\Local\Temp/ipykernel_21212/1303888392.py in generate_map(prep_map_data, bi_color, var_type, all_countries, week, bounds)
#     108     print(fig)
#     109
# --> 110     with open('png_files/' + week + '.png', 'x') as f:
#     111         pio.write_image(fig=fig, file='png_files/' + week + '.png', format='png')
#     112
#
# FileExistsError: [Errno 17] File exists: 'png_files/2020-40.png'
