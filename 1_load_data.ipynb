# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
variants = pd.read_csv("variant_cases.csv", sep=",", index_col=0)
vaccinations = pd.read_csv("vaccinations.csv", sep=',', index_col=0)

# %%
variants = variants.loc[(variants['variant'] == 'B.1.617.2') | (variants['variant'] == 'B.1.1.529') |\
                       (variants['variant'] == 'B.1.1.7') | (variants['variant'] == 'B.1.351')]

variants
# Out:
#         country_code year_week  source  new_cases  number_sequenced  \
# country
# Austria           AT   2020-40  GISAID       5597                 4
# Austria           AT   2020-40  GISAID       5597                 4
# Austria           AT   2020-40  GISAID       5597                 4
# Austria           AT   2020-40  GISAID       5597                 4
# Austria           AT   2020-41  GISAID       7486                26
# ...              ...       ...     ...        ...               ...
# Sweden            SE   2021-50   TESSy      24538              1951
# Sweden            SE   2021-51   TESSy      28046                32
# Sweden            SE   2021-51   TESSy      28046                32
# Sweden            SE   2021-52   TESSy      59466                36
# Sweden            SE   2021-52   TESSy      59466                36
#
#          percent_cases_sequenced valid_denominator    variant  \
# country
# Austria                      0.1               Yes  B.1.1.529
# Austria                      0.1               Yes    B.1.1.7
# Austria                      0.1               Yes    B.1.351
# Austria                      0.1               Yes  B.1.617.2
# Austria                      0.3               Yes  B.1.1.529
# ...                          ...               ...        ...
# Sweden                       8.0               Yes  B.1.617.2
# Sweden                       0.1               Yes  B.1.1.529
# Sweden                       0.1               Yes  B.1.617.2
# Sweden                       0.1               Yes  B.1.1.529
# Sweden                       0.1               Yes  B.1.617.2
#
#          number_detections_variant  number_sequenced_known_variant  \
# country
# Austria                          0                             4.0
# Austria                          0                             4.0
# Austria                          0                             4.0
# Austria                          0                             4.0
# Austria                          0                            26.0
# ...                            ...                             ...
# Sweden                        1340                          1951.0
# Sweden                          28                            32.0
# Sweden                           4                            32.0
# Sweden                          33                            36.0
# Sweden                           3                            36.0
#
#          percent_variant
# country
# Austria              0.0
# Austria              0.0
# Austria              0.0
# Austria              0.0
# Austria              0.0
# ...                  ...
# Sweden              68.7
# Sweden              87.5
# Sweden              12.5
# Sweden              91.7
# Sweden               8.3
#
# [10740 rows x 11 columns]

# %%
sort_variants = variants.sort_values('number_sequenced')
var = sort_variants.drop_duplicates(subset=['country_code', 'year_week', 'variant'], keep='last')
variants = var.sort_values(by=['country_code','year_week'])
variants
# Out:
#          country_code year_week  source  new_cases  number_sequenced  \
# country
# Austria            AT   2020-40  GISAID       5597                 4
# Austria            AT   2020-40  GISAID       5597                 4
# Austria            AT   2020-40  GISAID       5597                 4
# Austria            AT   2020-40  GISAID       5597                 4
# Austria            AT   2020-41  GISAID       7486                26
# ...               ...       ...     ...        ...               ...
# Slovakia           SK   2021-51   TESSy      19979               652
# Slovakia           SK   2021-52  GISAID      19839                 0
# Slovakia           SK   2021-52  GISAID      19839                 0
# Slovakia           SK   2021-52   TESSy      19839               233
# Slovakia           SK   2021-52   TESSy      19839               233
#
#           percent_cases_sequenced valid_denominator    variant  \
# country
# Austria                       0.1               Yes  B.1.1.529
# Austria                       0.1               Yes    B.1.1.7
# Austria                       0.1               Yes    B.1.351
# Austria                       0.1               Yes  B.1.617.2
# Austria                       0.3               Yes  B.1.1.529
# ...                           ...               ...        ...
# Slovakia                      3.3               Yes  B.1.1.529
# Slovakia                      0.0               Yes    B.1.1.7
# Slovakia                      0.0               Yes    B.1.351
# Slovakia                      1.2               Yes  B.1.617.2
# Slovakia                      1.2               Yes  B.1.1.529
#
#           number_detections_variant  number_sequenced_known_variant  \
# country
# Austria                           0                             4.0
# Austria                           0                             4.0
# Austria                           0                             4.0
# Austria                           0                             4.0
# Austria                           0                            26.0
# ...                             ...                             ...
# Slovakia                          4                           652.0
# Slovakia                          0                             0.0
# Slovakia                          0                             0.0
# Slovakia                        224                           233.0
# Slovakia                          9                           233.0
#
#           percent_variant
# country
# Austria               0.0
# Austria               0.0
# Austria               0.0
# Austria               0.0
# Austria               0.0
# ...                   ...
# Slovakia              0.6
# Slovakia              NaN
# Slovakia              NaN
# Slovakia             96.1
# Slovakia              3.9
#
# [7920 rows x 11 columns]

# %%
def get_variants(row):
    percentage = row['percent_variant']/100
    cases = row['new_cases'] * percentage
    return cases
    
variants['number_cases_ratio'] = variants.apply(get_variants, axis=1)
variants = variants.drop(columns=['source', 'number_sequenced', 'percent_cases_sequenced', 'valid_denominator',\
                                  'number_detections_variant', 'number_sequenced_known_variant'])
variants
# Out:
#          country_code year_week  new_cases    variant  percent_variant  \
# country
# Austria            AT   2020-40       5597  B.1.1.529              0.0
# Austria            AT   2020-40       5597    B.1.1.7              0.0
# Austria            AT   2020-40       5597    B.1.351              0.0
# Austria            AT   2020-40       5597  B.1.617.2              0.0
# Austria            AT   2020-41       7486  B.1.1.529              0.0
# ...               ...       ...        ...        ...              ...
# Slovakia           SK   2021-51      19979  B.1.1.529              0.6
# Slovakia           SK   2021-52      19839    B.1.1.7              NaN
# Slovakia           SK   2021-52      19839    B.1.351              NaN
# Slovakia           SK   2021-52      19839  B.1.617.2             96.1
# Slovakia           SK   2021-52      19839  B.1.1.529              3.9
#
#           number_cases_ratio
# country
# Austria                0.000
# Austria                0.000
# Austria                0.000
# Austria                0.000
# Austria                0.000
# ...                      ...
# Slovakia             119.874
# Slovakia                 NaN
# Slovakia                 NaN
# Slovakia           19065.279
# Slovakia             773.721
#
# [7920 rows x 6 columns]

# %%
variants = variants.loc[(variants['variant'] != 'B.1.351')]
variants
# Out:
#          country_code year_week  new_cases    variant  percent_variant  \
# country
# Austria            AT   2020-40       5597  B.1.1.529              0.0
# Austria            AT   2020-40       5597    B.1.1.7              0.0
# Austria            AT   2020-40       5597  B.1.617.2              0.0
# Austria            AT   2020-41       7486  B.1.1.529              0.0
# Austria            AT   2020-41       7486  B.1.617.2              0.0
# ...               ...       ...        ...        ...              ...
# Slovakia           SK   2021-51      19979  B.1.617.2             99.1
# Slovakia           SK   2021-51      19979  B.1.1.529              0.6
# Slovakia           SK   2021-52      19839    B.1.1.7              NaN
# Slovakia           SK   2021-52      19839  B.1.617.2             96.1
# Slovakia           SK   2021-52      19839  B.1.1.529              3.9
#
#           number_cases_ratio
# country
# Austria                0.000
# Austria                0.000
# Austria                0.000
# Austria                0.000
# Austria                0.000
# ...                      ...
# Slovakia           19799.189
# Slovakia             119.874
# Slovakia                 NaN
# Slovakia           19065.279
# Slovakia             773.721
#
# [5940 rows x 6 columns]

# %%
vaccinations = vaccinations.loc[vaccinations['TargetGroup'] == 'ALL']
vaccinations = vaccinations.drop_duplicates(subset='ReportingCountry')
vaccinations
# Out:
#             ReportingCountry  Denominator  NumberDosesReceived  \
# YearWeekISO
# 2020-W53                  AT    8901064.0                  0.0
# 2020-W53                  BE   11522440.0                  0.0
# 2020-W52                  BG    6951482.0              10725.0
# 2020-W52                  CY     888005.0               9750.0
# 2020-W52                  CZ   10693939.0              11700.0
# 2020-W52                  DE   83166711.0             151125.0
# 2020-W50                  DK    5822763.0                  0.0
# 2020-W52                  EE    1328976.0               9750.0
# 2020-W52                  EL   10718565.0                  0.0
# 2020-W53                  ES   47332614.0                  NaN
# 2020-W52                  FI          NaN                  NaN
# 2020-W53                  FR   67320216.0              58500.0
# 2020-W52                  HR    4058165.0                  NaN
# 2020-W52                  HU    9769526.0               9750.0
# 2020-W52                  IE    4964440.0               9750.0
# 2020-W53                  IS     364134.0              11700.0
# 2020-W52                  IT    3953305.0                  NaN
# 2021-W06                  LI      38747.0               1800.0
# 2020-W52                  LT     820511.0               2955.0
# 2020-W52                  LU     626108.0               9750.0
# 2020-W52                  LV    1907675.0               9750.0
# 2020-W52                  MT     514564.0                  NaN
# 2020-W52                  NL   17407585.0                  0.0
# 2020-W52                  NO    5367580.0               9750.0
# 2020-W52                  PL    1671605.0                  NaN
# 2020-W52                  PT          NaN                  NaN
# 2021-W04                  RO   19328838.0             926370.0
# 2020-W52                  SE     870200.0                  NaN
# 2020-W52                  SI    2095861.0              11700.0
# 2020-W52                  SK    5457873.0               9750.0
#
#              NumberDosesExported  FirstDose  FirstDoseRefused  SecondDose  \
# YearWeekISO
# 2020-W53                     0.0          0               NaN           0
# 2020-W53                     NaN          0               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN        369               NaN           0
# 2020-W52                     0.0       1268               NaN           0
# 2020-W52                     0.0      24346               NaN          19
# 2020-W50                     0.0          1               NaN           0
# 2020-W52                     0.0        191               NaN           0
# 2020-W52                     0.0          2               NaN           0
# 2020-W53                     NaN          0               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W53                     NaN     106225               NaN           0
# 2020-W52                     NaN         52               NaN          10
# 2020-W52                     NaN       1095               NaN           0
# 2020-W52                     0.0          0               NaN           0
# 2020-W53                     0.0       4943               NaN           0
# 2020-W52                     NaN        510               NaN           0
# 2021-W06                     0.0        368               NaN           0
# 2020-W52                     NaN        713               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN         57               NaN           0
# 2020-W52                     0.0          0               NaN           0
# 2020-W52                     NaN         68               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN         20               NaN           0
# 2021-W04                     NaN     586514               0.0      106470
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN       6200               NaN           0
# 2020-W52                     0.0          0               NaN           0
#
#              DoseAdditional1  UnknownDose   Region TargetGroup Vaccine  \
# YearWeekISO
# 2020-W53                   0            0       AT         ALL     MOD
# 2020-W53                   0            0       BE         ALL   JANSS
# 2020-W52                   0            0       BG         ALL     COM
# 2020-W52                   0            0       CY         ALL     COM
# 2020-W52                   0            0       CZ         ALL     COM
# 2020-W52                   0            0       DE         ALL     COM
# 2020-W50                   0            0       DK         ALL     COM
# 2020-W52                   0            0       EE         ALL     COM
# 2020-W52                   0            0       EL         ALL     MOD
# 2020-W53                   0            0       ES         ALL   JANSS
# 2020-W52                   0            0    FI197         ALL   JANSS
# 2020-W53                   0            0       FR         ALL     COM
# 2020-W52                   0            0       HR         ALL     UNK
# 2020-W52                   0            0       HU         ALL     COM
# 2020-W52                   0            0       IE         ALL     COM
# 2020-W53                   0            0       IS         ALL     COM
# 2020-W52                   0            0     ITF4         ALL     COM
# 2021-W06                   0            0       LI         ALL     MOD
# 2020-W52                   0            0     LT01         ALL     COM
# 2020-W52                   0            0       LU         ALL     COM
# 2020-W52                   0            0       LV         ALL     COM
# 2020-W52                   0            0       MT         ALL     COM
# 2020-W52                   0            0       NL         ALL     MOD
# 2020-W52                   0            0       NO         ALL     COM
# 2020-W52                   0            0     PL42         ALL     MOD
# 2020-W52                   0            0  PTCSR01         ALL     COM
# 2021-W04                   0            0       RO         ALL     COM
# 2020-W52                   0            0     SE21         ALL      AZ
# 2020-W52                   0            0       SI         ALL     COM
# 2020-W52                   0            0       SK         ALL     COM
#
#              Population
# YearWeekISO
# 2020-W53        8901064
# 2020-W53       11522440
# 2020-W52        6951482
# 2020-W52         888005
# 2020-W52       10693939
# 2020-W52       83166711
# 2020-W50        5822763
# 2020-W52        1328976
# 2020-W52       10718565
# 2020-W53       47332614
# 2020-W52        5525292
# 2020-W53       67320216
# 2020-W52        4058165
# 2020-W52        9769526
# 2020-W52        4964440
# 2020-W53         364134
# 2020-W52       59641488
# 2021-W06          38747
# 2020-W52        2794090
# 2020-W52         626108
# 2020-W52        1907675
# 2020-W52         514564
# 2020-W52       17407585
# 2020-W52        5367580
# 2020-W52       37958138
# 2020-W52       10295909
# 2021-W04       19328838
# 2020-W52       10327589
# 2020-W52        2095861
# 2020-W52        5457873

# %%
def get_population(row, df):
    pop = df['Population'].loc[df['ReportingCountry'] == row['country_code']]
    return pop[0]

variants['population'] = variants.apply(lambda row: get_population(row,vaccinations), axis=1)
variants
# Out:
#          country_code year_week  new_cases    variant  percent_variant  \
# country
# Austria            AT   2020-40       5597  B.1.1.529              0.0
# Austria            AT   2020-40       5597    B.1.1.7              0.0
# Austria            AT   2020-40       5597  B.1.617.2              0.0
# Austria            AT   2020-41       7486  B.1.1.529              0.0
# Austria            AT   2020-41       7486  B.1.617.2              0.0
# ...               ...       ...        ...        ...              ...
# Slovakia           SK   2021-51      19979  B.1.617.2             99.1
# Slovakia           SK   2021-51      19979  B.1.1.529              0.6
# Slovakia           SK   2021-52      19839    B.1.1.7              NaN
# Slovakia           SK   2021-52      19839  B.1.617.2             96.1
# Slovakia           SK   2021-52      19839  B.1.1.529              3.9
#
#           number_cases_ratio  population
# country
# Austria                0.000     8901064
# Austria                0.000     8901064
# Austria                0.000     8901064
# Austria                0.000     8901064
# Austria                0.000     8901064
# ...                      ...         ...
# Slovakia           19799.189     5457873
# Slovakia             119.874     5457873
# Slovakia                 NaN     5457873
# Slovakia           19065.279     5457873
# Slovakia             773.721     5457873
#
# [5940 rows x 7 columns]

# %%
def normalize_counts(row):
    percentage = (row['number_cases_ratio']/row['population']) * 100
    return percentage
    
variants['normalized_counts'] = variants.apply(normalize_counts, axis=1)

variants = variants.reset_index()
variants
# Out:
#        country country_code year_week  new_cases    variant  percent_variant  \
# 0      Austria           AT   2020-40       5597  B.1.1.529              0.0
# 1      Austria           AT   2020-40       5597    B.1.1.7              0.0
# 2      Austria           AT   2020-40       5597  B.1.617.2              0.0
# 3      Austria           AT   2020-41       7486  B.1.1.529              0.0
# 4      Austria           AT   2020-41       7486  B.1.617.2              0.0
# ...        ...          ...       ...        ...        ...              ...
# 5935  Slovakia           SK   2021-51      19979  B.1.617.2             99.1
# 5936  Slovakia           SK   2021-51      19979  B.1.1.529              0.6
# 5937  Slovakia           SK   2021-52      19839    B.1.1.7              NaN
# 5938  Slovakia           SK   2021-52      19839  B.1.617.2             96.1
# 5939  Slovakia           SK   2021-52      19839  B.1.1.529              3.9
#
#       number_cases_ratio  population  normalized_counts
# 0                  0.000     8901064           0.000000
# 1                  0.000     8901064           0.000000
# 2                  0.000     8901064           0.000000
# 3                  0.000     8901064           0.000000
# 4                  0.000     8901064           0.000000
# ...                  ...         ...                ...
# 5935           19799.189     5457873           0.362764
# 5936             119.874     5457873           0.002196
# 5937                 NaN     5457873                NaN
# 5938           19065.279     5457873           0.349317
# 5939             773.721     5457873           0.014176
#
# [5940 rows x 9 columns]

# %%
variant_data = variants[["variant","normalized_counts"]]#.reset_index(drop=True)
variant_data_p = variant_data.pivot(columns = ["variant"], values = ["normalized_counts"])
variant_data_p = variant_data_p.droplevel(level = 0, axis = 1)
week_data = pd.DataFrame(variants[["country","country_code","year_week","new_cases","population"]]).reset_index(drop=True)
week_data.index.rename("variant", inplace = True)
combined = week_data.join(variant_data_p, on="variant").reset_index(drop=True)
combined
# Out:
#        country country_code year_week  new_cases  population  B.1.1.529  \
# 0      Austria           AT   2020-40       5597     8901064   0.000000
# 1      Austria           AT   2020-40       5597     8901064        NaN
# 2      Austria           AT   2020-40       5597     8901064        NaN
# 3      Austria           AT   2020-41       7486     8901064   0.000000
# 4      Austria           AT   2020-41       7486     8901064        NaN
# ...        ...          ...       ...        ...         ...        ...
# 5935  Slovakia           SK   2021-51      19979     5457873        NaN
# 5936  Slovakia           SK   2021-51      19979     5457873   0.002196
# 5937  Slovakia           SK   2021-52      19839     5457873        NaN
# 5938  Slovakia           SK   2021-52      19839     5457873        NaN
# 5939  Slovakia           SK   2021-52      19839     5457873   0.014176
#
#       B.1.1.7  B.1.617.2
# 0         NaN        NaN
# 1         0.0        NaN
# 2         NaN   0.000000
# 3         NaN        NaN
# 4         NaN   0.000000
# ...       ...        ...
# 5935      NaN   0.362764
# 5936      NaN        NaN
# 5937      NaN        NaN
# 5938      NaN   0.349317
# 5939      NaN        NaN
#
# [5940 rows x 8 columns]

# %%
data = []
for idx, row in combined.iterrows():
    row_list = []
    if idx > 1:
        prev = (idx - 1)
        if row["year_week"] == list(combined.loc[combined.index == prev]["year_week"])[0]:
            if pd.isna(row["B.1.1.529"]):
                row["B.1.1.529"] = list(combined.loc[combined.index == prev]["B.1.1.529"])[0]
            if pd.isna(row["B.1.1.7"]):
                row["B.1.1.7"] = list(combined.loc[combined.index == prev]["B.1.1.7"])[0]
            if pd.isna(row["B.1.617.2"]):
                row["B.1.617.2"] = list(combined.loc[combined.index == prev]["B.1.617.2"])[0]
        if row["year_week"] == list(combined.loc[combined.index == prev - 1]["year_week"])[0]:
            if pd.isna(row["B.1.1.529"]):
                row["B.1.1.529"] = list(combined.loc[combined.index == prev - 1]["B.1.1.529"])[0]
            if pd.isna(row["B.1.1.7"]):
                row["B.1.1.7"] = list(combined.loc[combined.index == prev - 1]["B.1.1.7"])[0]
            if pd.isna(row["B.1.617.2"]):
                row["B.1.617.2"] = list(combined.loc[combined.index == prev - 1]["B.1.617.2"])[0]
                
        row_list.append(row["country"]) 
        row_list.append(row["country_code"])
        row_list.append(row["year_week"])
        row_list.append(row["new_cases"])
        row_list.append(row["B.1.1.529"])
        row_list.append(row["B.1.1.7"])
        row_list.append(row["B.1.617.2"])
        row_list.append(row["population"])
        data.append(row_list)

# %%
updated_df = pd.DataFrame(data,columns=["Country","Country_Code","Year_Week","New_Cases","B.1.1.529","B.1.1.7","B.1.617.2",
                                       "Population"])
updated_df = updated_df.dropna(thresh=6)
updated_df = updated_df.drop_duplicates(subset=['Country_Code', 'Year_Week'], keep='last')
updated_df = updated_df.set_index("Country")
updated_df
# Out:
#          Country_Code Year_Week  New_Cases  B.1.1.529  B.1.1.7  B.1.617.2  \
# Country
# Austria            AT   2020-40       5597   0.000000      0.0   0.000000
# Austria            AT   2020-41       7486   0.000000      0.0   0.000000
# Austria            AT   2020-42       9903   0.000000      0.0   0.000000
# Austria            AT   2020-43      18274   0.000000      0.0   0.000000
# Austria            AT   2020-44      31613   0.000000      0.0   0.000000
# ...               ...       ...        ...        ...      ...        ...
# Slovakia           SK   2021-48      61314   0.004494      0.0   1.121158
# Slovakia           SK   2021-49      44995   0.004946      0.0   0.798849
# Slovakia           SK   2021-50      31044   0.002275      0.0   0.564811
# Slovakia           SK   2021-51      19979   0.002196      0.0   0.362764
# Slovakia           SK   2021-52      19839   0.014176      NaN   0.349317
#
#           Population
# Country
# Austria      8901064
# Austria      8901064
# Austria      8901064
# Austria      8901064
# Austria      8901064
# ...              ...
# Slovakia     5457873
# Slovakia     5457873
# Slovakia     5457873
# Slovakia     5457873
# Slovakia     5457873
#
# [1880 rows x 7 columns]

# %%
# variants.to_csv("data.tsv", sep="\t")
updated_df.to_csv("updated_data.tsv", sep="\t")
