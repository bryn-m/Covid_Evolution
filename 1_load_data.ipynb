# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
variants = pd.read_csv("variant_cases.csv", sep=",", index_col=0)
vaccinations = pd.read_csv("vaccinations.csv", sep=',', index_col=0)

# %%
variants = variants.loc[(variants['variant'] == 'B.1.617.2') | (variants['variant'] == 'B.1.1.529') |\
                       (variants['variant'] == 'B.1.1.7') | (variants['variant'] == 'B.1.351')]
#variants['variant_name'] = np.where(variants['variant'] == 'B.1.1.529', 'omicron', 'delta')
variants
# Out:
#         country_code year_week  source  new_cases  number_sequenced  \
# country
# Austria           AT   2020-40  GISAID       5597                 4
# Austria           AT   2020-40  GISAID       5597                 4
# Austria           AT   2020-40  GISAID       5597                 4
# Austria           AT   2020-40  GISAID       5597                 4
# Austria           AT   2020-41  GISAID       7486                26
# ...              ...       ...     ...        ...               ...
# Sweden            SE   2021-50   TESSy      24538              1951
# Sweden            SE   2021-51   TESSy      28046                32
# Sweden            SE   2021-51   TESSy      28046                32
# Sweden            SE   2021-52   TESSy      59466                36
# Sweden            SE   2021-52   TESSy      59466                36
#
#          percent_cases_sequenced valid_denominator    variant  \
# country
# Austria                      0.1               Yes  B.1.1.529
# Austria                      0.1               Yes    B.1.1.7
# Austria                      0.1               Yes    B.1.351
# Austria                      0.1               Yes  B.1.617.2
# Austria                      0.3               Yes  B.1.1.529
# ...                          ...               ...        ...
# Sweden                       8.0               Yes  B.1.617.2
# Sweden                       0.1               Yes  B.1.1.529
# Sweden                       0.1               Yes  B.1.617.2
# Sweden                       0.1               Yes  B.1.1.529
# Sweden                       0.1               Yes  B.1.617.2
#
#          number_detections_variant  number_sequenced_known_variant  \
# country
# Austria                          0                             4.0
# Austria                          0                             4.0
# Austria                          0                             4.0
# Austria                          0                             4.0
# Austria                          0                            26.0
# ...                            ...                             ...
# Sweden                        1340                          1951.0
# Sweden                          28                            32.0
# Sweden                           4                            32.0
# Sweden                          33                            36.0
# Sweden                           3                            36.0
#
#          percent_variant
# country
# Austria              0.0
# Austria              0.0
# Austria              0.0
# Austria              0.0
# Austria              0.0
# ...                  ...
# Sweden              68.7
# Sweden              87.5
# Sweden              12.5
# Sweden              91.7
# Sweden               8.3
#
# [10740 rows x 11 columns]

# %%
def get_variants(row):
    percentage = row['percent_variant']/100
    cases = row['new_cases'] * percentage
    return cases
    
variants['number_cases_ratio'] = variants.apply(get_variants, axis=1)
variants = variants.drop(columns=['source', 'number_sequenced', 'percent_cases_sequenced', 'valid_denominator',\
                                  'number_detections_variant', 'number_sequenced_known_variant'])
variants
# Out:
#         country_code year_week  new_cases    variant  percent_variant  \
# country
# Austria           AT   2020-40       5597  B.1.1.529              0.0
# Austria           AT   2020-40       5597    B.1.1.7              0.0
# Austria           AT   2020-40       5597    B.1.351              0.0
# Austria           AT   2020-40       5597  B.1.617.2              0.0
# Austria           AT   2020-41       7486  B.1.1.529              0.0
# ...              ...       ...        ...        ...              ...
# Sweden            SE   2021-50      24538  B.1.617.2             68.7
# Sweden            SE   2021-51      28046  B.1.1.529             87.5
# Sweden            SE   2021-51      28046  B.1.617.2             12.5
# Sweden            SE   2021-52      59466  B.1.1.529             91.7
# Sweden            SE   2021-52      59466  B.1.617.2              8.3
#
#          number_cases_ratio
# country
# Austria               0.000
# Austria               0.000
# Austria               0.000
# Austria               0.000
# Austria               0.000
# ...                     ...
# Sweden            16857.606
# Sweden            24540.250
# Sweden             3505.750
# Sweden            54530.322
# Sweden             4935.678
#
# [10740 rows x 6 columns]

# %%
df = variants.groupby(by=['year_week', 'variant']).sum()
df = df.reset_index()
x = df['year_week'].unique()

plt.rcParams['figure.figsize']=(15,10)
fig, ax = plt.subplots()

ax.plot(x, df['number_cases_ratio'].loc[df['variant']=='B.1.1.7'], label='Alpha')
ax.plot(x, df['number_cases_ratio'].loc[df['variant']=='B.1.351'], label='Beta')
ax.plot(x, df['number_cases_ratio'].loc[df['variant']=='B.1.617.2'], label='Delta')
ax.plot(x, df['number_cases_ratio'].loc[df['variant']=='B.1.1.529'], label="Omicron")

ax.set(xticks=x[::4])
plt.xticks(rotation = 45)
plt.title("Total Variant Case Count Per Week", fontsize=24)
plt.xlabel("Week", fontsize=18)
plt.ylabel("Total Variant Count", fontsize=18)
plt.legend(loc='upper left', prop={'size': 18})
plt.show()

#fig = plt.get_figure()
fig.savefig('Figure_2.png')

# %%
variants = variants.loc[(variants['variant'] != 'B.1.351')]
variants
# Out:
#         country_code year_week  new_cases    variant  percent_variant  \
# country
# Austria           AT   2020-40       5597  B.1.1.529              0.0
# Austria           AT   2020-40       5597    B.1.1.7              0.0
# Austria           AT   2020-40       5597  B.1.617.2              0.0
# Austria           AT   2020-41       7486  B.1.1.529              0.0
# Austria           AT   2020-41       7486    B.1.1.7              0.0
# ...              ...       ...        ...        ...              ...
# Sweden            SE   2021-50      24538  B.1.617.2             68.7
# Sweden            SE   2021-51      28046  B.1.1.529             87.5
# Sweden            SE   2021-51      28046  B.1.617.2             12.5
# Sweden            SE   2021-52      59466  B.1.1.529             91.7
# Sweden            SE   2021-52      59466  B.1.617.2              8.3
#
#          number_cases_ratio
# country
# Austria               0.000
# Austria               0.000
# Austria               0.000
# Austria               0.000
# Austria               0.000
# ...                     ...
# Sweden            16857.606
# Sweden            24540.250
# Sweden             3505.750
# Sweden            54530.322
# Sweden             4935.678
#
# [8197 rows x 6 columns]

# %%
vaccinations = vaccinations.loc[vaccinations['TargetGroup'] == 'ALL']
vaccinations = vaccinations.drop_duplicates(subset='ReportingCountry')
vaccinations
# Out:
#             ReportingCountry  Denominator  NumberDosesReceived  \
# YearWeekISO
# 2020-W53                  AT    8901064.0                  0.0
# 2020-W53                  BE   11522440.0                  0.0
# 2020-W52                  BG    6951482.0              10725.0
# 2020-W52                  CY     888005.0               9750.0
# 2020-W52                  CZ   10693939.0              11700.0
# 2020-W52                  DE   83166711.0             151125.0
# 2020-W50                  DK    5822763.0                  0.0
# 2020-W52                  EE    1328976.0               9750.0
# 2020-W52                  EL   10718565.0                  0.0
# 2020-W53                  ES   47332614.0                  NaN
# 2020-W52                  FI          NaN                  NaN
# 2020-W53                  FR   67320216.0              58500.0
# 2020-W52                  HR    4058165.0                  NaN
# 2020-W52                  HU    9769526.0               9750.0
# 2020-W52                  IE    4964440.0               9750.0
# 2020-W53                  IS     364134.0              11700.0
# 2020-W52                  IT    3953305.0                  NaN
# 2021-W06                  LI      38747.0               1800.0
# 2020-W52                  LT     820511.0               2955.0
# 2020-W52                  LU     626108.0               9750.0
# 2020-W52                  LV    1907675.0               9750.0
# 2020-W52                  MT     514564.0                  NaN
# 2020-W52                  NL   17407585.0                  0.0
# 2020-W52                  NO    5367580.0               9750.0
# 2020-W52                  PL    1671605.0                  NaN
# 2020-W52                  PT          NaN                  NaN
# 2021-W04                  RO   19328838.0             926370.0
# 2020-W52                  SE     870200.0                  NaN
# 2020-W52                  SI    2095861.0              11700.0
# 2020-W52                  SK    5457873.0               9750.0
#
#              NumberDosesExported  FirstDose  FirstDoseRefused  SecondDose  \
# YearWeekISO
# 2020-W53                     0.0          0               NaN           0
# 2020-W53                     NaN          0               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN        369               NaN           0
# 2020-W52                     0.0       1268               NaN           0
# 2020-W52                     0.0      24346               NaN          19
# 2020-W50                     0.0          1               NaN           0
# 2020-W52                     0.0        191               NaN           0
# 2020-W52                     0.0          2               NaN           0
# 2020-W53                     NaN          0               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W53                     NaN     106225               NaN           0
# 2020-W52                     NaN         52               NaN          10
# 2020-W52                     NaN       1095               NaN           0
# 2020-W52                     0.0          0               NaN           0
# 2020-W53                     0.0       4943               NaN           0
# 2020-W52                     NaN        510               NaN           0
# 2021-W06                     0.0        368               NaN           0
# 2020-W52                     NaN        713               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN         57               NaN           0
# 2020-W52                     0.0          0               NaN           0
# 2020-W52                     NaN         68               NaN           0
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN         20               NaN           0
# 2021-W04                     NaN     586514               0.0      106470
# 2020-W52                     NaN          0               NaN           0
# 2020-W52                     NaN       6200               NaN           0
# 2020-W52                     0.0          0               NaN           0
#
#              DoseAdditional1  UnknownDose   Region TargetGroup Vaccine  \
# YearWeekISO
# 2020-W53                   0            0       AT         ALL     MOD
# 2020-W53                   0            0       BE         ALL   JANSS
# 2020-W52                   0            0       BG         ALL     COM
# 2020-W52                   0            0       CY         ALL     COM
# 2020-W52                   0            0       CZ         ALL     COM
# 2020-W52                   0            0       DE         ALL     COM
# 2020-W50                   0            0       DK         ALL     COM
# 2020-W52                   0            0       EE         ALL     COM
# 2020-W52                   0            0       EL         ALL     MOD
# 2020-W53                   0            0       ES         ALL   JANSS
# 2020-W52                   0            0    FI197         ALL   JANSS
# 2020-W53                   0            0       FR         ALL     COM
# 2020-W52                   0            0       HR         ALL     UNK
# 2020-W52                   0            0       HU         ALL     COM
# 2020-W52                   0            0       IE         ALL     COM
# 2020-W53                   0            0       IS         ALL     COM
# 2020-W52                   0            0     ITF4         ALL     COM
# 2021-W06                   0            0       LI         ALL     MOD
# 2020-W52                   0            0     LT01         ALL     COM
# 2020-W52                   0            0       LU         ALL     COM
# 2020-W52                   0            0       LV         ALL     COM
# 2020-W52                   0            0       MT         ALL     COM
# 2020-W52                   0            0       NL         ALL     MOD
# 2020-W52                   0            0       NO         ALL     COM
# 2020-W52                   0            0     PL42         ALL     MOD
# 2020-W52                   0            0  PTCSR01         ALL     COM
# 2021-W04                   0            0       RO         ALL     COM
# 2020-W52                   0            0     SE21         ALL      AZ
# 2020-W52                   0            0       SI         ALL     COM
# 2020-W52                   0            0       SK         ALL     COM
#
#              Population
# YearWeekISO
# 2020-W53        8901064
# 2020-W53       11522440
# 2020-W52        6951482
# 2020-W52         888005
# 2020-W52       10693939
# 2020-W52       83166711
# 2020-W50        5822763
# 2020-W52        1328976
# 2020-W52       10718565
# 2020-W53       47332614
# 2020-W52        5525292
# 2020-W53       67320216
# 2020-W52        4058165
# 2020-W52        9769526
# 2020-W52        4964440
# 2020-W53         364134
# 2020-W52       59641488
# 2021-W06          38747
# 2020-W52        2794090
# 2020-W52         626108
# 2020-W52        1907675
# 2020-W52         514564
# 2020-W52       17407585
# 2020-W52        5367580
# 2020-W52       37958138
# 2020-W52       10295909
# 2021-W04       19328838
# 2020-W52       10327589
# 2020-W52        2095861
# 2020-W52        5457873

# %%
def get_population(row, df):
    pop = df['Denominator'].loc[df['ReportingCountry'] == row['country_code']]
    return pop[0]

variants['population'] = variants.apply(lambda row: get_population(row,vaccinations), axis=1)
variants
# Out:
# /var/folders/j0/0b933hxd0_j8p66b657g5fb40000gn/T/ipykernel_64745/3869827783.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   variants['population'] = variants.apply(lambda row: get_population(row,vaccinations), axis=1)
#         country_code year_week  new_cases    variant  percent_variant  \
# country
# Austria           AT   2020-40       5597  B.1.1.529              0.0
# Austria           AT   2020-40       5597    B.1.1.7              0.0
# Austria           AT   2020-40       5597  B.1.617.2              0.0
# Austria           AT   2020-41       7486  B.1.1.529              0.0
# Austria           AT   2020-41       7486    B.1.1.7              0.0
# ...              ...       ...        ...        ...              ...
# Sweden            SE   2021-50      24538  B.1.617.2             68.7
# Sweden            SE   2021-51      28046  B.1.1.529             87.5
# Sweden            SE   2021-51      28046  B.1.617.2             12.5
# Sweden            SE   2021-52      59466  B.1.1.529             91.7
# Sweden            SE   2021-52      59466  B.1.617.2              8.3
#
#          number_cases_ratio  population
# country
# Austria               0.000   8901064.0
# Austria               0.000   8901064.0
# Austria               0.000   8901064.0
# Austria               0.000   8901064.0
# Austria               0.000   8901064.0
# ...                     ...         ...
# Sweden            16857.606    870200.0
# Sweden            24540.250    870200.0
# Sweden             3505.750    870200.0
# Sweden            54530.322    870200.0
# Sweden             4935.678    870200.0
#
# [8197 rows x 7 columns]

# %%
def normalize_counts(row):
    percentage = (row['number_cases_ratio']/row['population'])
    return percentage
    
variants['normalized_counts'] = variants.apply(normalize_counts, axis=1)

variants = variants.reset_index()
variants
# Out:
# /var/folders/j0/0b933hxd0_j8p66b657g5fb40000gn/T/ipykernel_64745/1392307840.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   variants['normalized_counts'] = variants.apply(normalize_counts, axis=1)
#       country country_code year_week  new_cases    variant  percent_variant  \
# 0     Austria           AT   2020-40       5597  B.1.1.529              0.0
# 1     Austria           AT   2020-40       5597    B.1.1.7              0.0
# 2     Austria           AT   2020-40       5597  B.1.617.2              0.0
# 3     Austria           AT   2020-41       7486  B.1.1.529              0.0
# 4     Austria           AT   2020-41       7486    B.1.1.7              0.0
# ...       ...          ...       ...        ...        ...              ...
# 8192   Sweden           SE   2021-50      24538  B.1.617.2             68.7
# 8193   Sweden           SE   2021-51      28046  B.1.1.529             87.5
# 8194   Sweden           SE   2021-51      28046  B.1.617.2             12.5
# 8195   Sweden           SE   2021-52      59466  B.1.1.529             91.7
# 8196   Sweden           SE   2021-52      59466  B.1.617.2              8.3
#
#          number_cases_ratio  population  normalized_counts
# country
# Austria               0.000   8901064.0           0.000000
# Austria               0.000   8901064.0           0.000000
# Austria               0.000   8901064.0           0.000000
# Austria               0.000   8901064.0           0.000000
# Austria               0.000   8901064.0           0.000000
# ...                     ...         ...                ...
# Sweden            16857.606    870200.0           0.019372
# Sweden            24540.250    870200.0           0.028201
# Sweden             3505.750    870200.0           0.004029
# Sweden            54530.322    870200.0           0.062664
# Sweden             4935.678    870200.0           0.005672
#
# [8197 rows x 9 columns]

# %%
variants = variants.drop(columns=['country_code', 'percent_variant', 'number_cases_ratio', 'population'])

# %%
dfs = variants.groupby(by='variant')


new_df=pd.merge(dfs.get_group('B.1.1.529'), dfs.get_group('B.1.1.7'), on=['country', 'year_week', 'new_cases'])
new_df=pd.merge(new_df, dfs.get_group('B.1.617.2'), on=['country', 'year_week', 'new_cases'])
new_df = new_df.rename(columns={'normalized_counts_x':'omicron', 'normalized_counts_y':'alpha', 'normalized_counts': 'delta'})
new_df = new_df.drop(columns=['variant_x', 'variant_y', 'variant'])
new_df.tail(10)
# Out:
#      country year_week  new_cases   omicron  alpha     delta
# 5099  Sweden   2021-50      24538  0.008826    0.0  0.020528
# 5100  Sweden   2021-50      24538  0.008826    0.0  0.019372
# 5101  Sweden   2021-51      28046  0.022367    0.0  0.009475
# 5102  Sweden   2021-51      28046  0.022367    0.0  0.004029
# 5103  Sweden   2021-51      28046  0.028201    0.0  0.009475
# 5104  Sweden   2021-51      28046  0.028201    0.0  0.004029
# 5105  Sweden   2021-52      59466       NaN    NaN       NaN
# 5106  Sweden   2021-52      59466       NaN    NaN  0.005672
# 5107  Sweden   2021-52      59466  0.062664    NaN       NaN
# 5108  Sweden   2021-52      59466  0.062664    NaN  0.005672

# %%
dfs.get_group('B.1.1.529')
# Out:
#       country year_week  new_cases    variant  normalized_counts
# 0     Austria   2020-40       5597  B.1.1.529           0.000000
# 3     Austria   2020-41       7486  B.1.1.529           0.000000
# 6     Austria   2020-42       9903  B.1.1.529           0.000000
# 9     Austria   2020-43      18274  B.1.1.529           0.000000
# 12    Austria   2020-44      31613  B.1.1.529           0.000000
# ...       ...       ...        ...        ...                ...
# 8187   Sweden   2021-48      13800  B.1.1.529           0.000190
# 8189   Sweden   2021-49      18651  B.1.1.529           0.001500
# 8191   Sweden   2021-50      24538  B.1.1.529           0.008826
# 8193   Sweden   2021-51      28046  B.1.1.529           0.028201
# 8195   Sweden   2021-52      59466  B.1.1.529           0.062664
#
# [2115 rows x 5 columns]

# %%
dfs.get_group('B.1.1.7')
# Out:
#       country year_week  new_cases  variant  normalized_counts
# 1     Austria   2020-40       5597  B.1.1.7           0.000000
# 4     Austria   2020-41       7486  B.1.1.7           0.000000
# 7     Austria   2020-42       9903  B.1.1.7           0.000000
# 10    Austria   2020-43      18274  B.1.1.7           0.000000
# 13    Austria   2020-44      31613  B.1.1.7           0.000000
# ...       ...       ...        ...      ...                ...
# 8163   Sweden   2021-32       5819  B.1.1.7           0.000020
# 8165   Sweden   2021-33       6464  B.1.1.7           0.000007
# 8167   Sweden   2021-34       6688  B.1.1.7           0.000008
# 8169   Sweden   2021-35       7239  B.1.1.7           0.000000
# 8175   Sweden   2021-39       4232  B.1.1.7           0.000000
#
# [3013 rows x 5 columns]

# %%
variants.to_csv("data.tsv", sep="\t")
updated_df.to_csv("updated_data.tsv", sep="\t")
